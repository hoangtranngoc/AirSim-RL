# %% [markdown]
# ### this notebook is a copy of train.py

# %%
from rl.callbacks import ModelIntervalCheckpoint, FileLogger
from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, Concatenate
from gym import spaces
import numpy as np
from PIL import Image
from configparser import ConfigParser
import os
from os.path import join, pardir, exists

from gym_airsim.airsim_car_env import AirSimCarEnv

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  #dynamically grow the memory used on the GPU
set_session(tf.Session(config=config))

class AirSimCarProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')  # resize and convert to grayscale
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

config = ConfigParser()
config.read('config.ini')
num_actions = int(config['car_agent']['actions'])
                    
WINDOW_LENGTH = 4
INPUT_SHAPE = (84, 84)

env = AirSimCarEnv()
np.random.seed(123)

# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
model.add(Permute((2, 3, 1), input_shape=input_shape))
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(num_actions))
model.add(Activation('linear'))
print(model.summary())

log_dir = 'logs'
if not exists(log_dir):
    os.makedirs(log_dir)

memory = SequentialMemory(limit=50000, window_length=WINDOW_LENGTH)
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(),  attr='eps', value_max=1., 
                              value_min=.1, value_test=.05, nb_steps=1000000)
processor = AirSimCarProcessor()

dqn = DQNAgent(model=model, nb_actions=num_actions, policy=policy, memory=memory,
               processor=processor, nb_steps_warmup=50000, gamma=.99, target_model_update=10000,
               train_interval=4, delta_clip=1.)
dqn.compile(Adam(lr=.0001), metrics=['mae'])

def build_callbacks(env_name):
    log_dir = 'logs'
    if not exists(log_dir):
        os.makedirs(log_dir)
    
    checkpoint_weights_filename = join(log_dir, 'dqn_' + env_name + '_weights_{step}.h5f')
    log_filename = join(log_dir,'dqn_{}_log.json'.format(env_name))
    callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=25000)]
    callbacks += [FileLogger(log_filename, interval=100)]
    return callbacks

callbacks = build_callbacks('AirSimCarRL')

dqn.fit(env, nb_steps=2000000,
        visualize=False,
        verbose=2,
        callbacks=callbacks)

# def build_callbacks_cont(env_name):
#     checkpoint_weights_filename = join(log_dir, 'dqn_' + env_name + '_weights_500000_add_{step}.h5f')
#     log_filename = join(log_dir,'dqn_{}_log.json'.format(env_name))
#     callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=25000)]
#     callbacks += [FileLogger(log_filename, interval=100)]
#     return callbacks

# callbacks_cont = build_callbacks_cont('AirSimCarRL')

# dqn = DQNAgent(model=model, nb_actions=num_actions, policy=policy, memory=memory,
#                processor=processor, nb_steps_warmup=50000, gamma=.99, target_model_update=10000,
#                train_interval=4, delta_clip=1.)
# dqn.compile(Adam(lr=.0001), metrics=['mae'])

# weights_filename = join(log_dir,'dqn_{}_weights_{}.h5f'.format('AirSimCarRL', 500000))
# dqn.load_weights(weights_filename)

# dqn.fit(env, nb_steps=2000000,
#         visualize=False,
#         verbose=2,
#         callbacks=callbacks_cont)
# Out:
# Using TensorFlow backend.
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)
#
# ['WayPoint0', 'WayPoint1', 'WayPoint2', 'WayPoint3', 'WayPoint4', 'WayPoint5', 'WayPoint6', 'WayPoint7', 'WayPoint8', 'WayPoint9']
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation_5 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 1,687,719
# Trainable params: 1,687,719
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\rl\util.py:79: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Training for 2000000 steps ...
#      300/2000000: episode: 1, duration: 10.743s, episode steps: 300, steps per second: 28, episode reward: 119.300, mean reward: 0.398 [-1.000, 0.500], mean action: 3.057 [0.000, 6.000], mean observation: 171.490 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#      616/2000000: episode: 2, duration: 10.028s, episode steps: 316, steps per second: 32, episode reward: 227.900, mean reward: 0.721 [-1.000, 1.000], mean action: 3.054 [0.000, 6.000], mean observation: 171.714 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#      933/2000000: episode: 3, duration: 9.507s, episode steps: 317, steps per second: 33, episode reward: 161.600, mean reward: 0.510 [-1.000, 1.000], mean action: 3.060 [0.000, 6.000], mean observation: 171.622 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     1239/2000000: episode: 4, duration: 8.626s, episode steps: 306, steps per second: 35, episode reward: 125.500, mean reward: 0.410 [-1.000, 0.500], mean action: 2.948 [0.000, 6.000], mean observation: 172.097 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     1550/2000000: episode: 5, duration: 8.882s, episode steps: 311, steps per second: 35, episode reward: 130.000, mean reward: 0.418 [-1.000, 0.500], mean action: 2.897 [0.000, 6.000], mean observation: 172.314 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     1868/2000000: episode: 6, duration: 9.342s, episode steps: 318, steps per second: 34, episode reward: 201.300, mean reward: 0.633 [-1.000, 1.000], mean action: 2.931 [0.000, 6.000], mean observation: 171.601 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     2219/2000000: episode: 7, duration: 10.706s, episode steps: 351, steps per second: 33, episode reward: 213.500, mean reward: 0.608 [-1.000, 1.000], mean action: 3.003 [0.000, 6.000], mean observation: 172.635 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     2532/2000000: episode: 8, duration: 9.059s, episode steps: 313, steps per second: 35, episode reward: 166.000, mean reward: 0.530 [-1.000, 1.000], mean action: 2.958 [0.000, 6.000], mean observation: 171.802 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     2856/2000000: episode: 9, duration: 9.635s, episode steps: 324, steps per second: 34, episode reward: 197.900, mean reward: 0.611 [-1.000, 1.000], mean action: 3.049 [0.000, 6.000], mean observation: 172.203 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     3168/2000000: episode: 10, duration: 9.320s, episode steps: 312, steps per second: 33, episode reward: 146.200, mean reward: 0.469 [-1.000, 1.000], mean action: 3.026 [0.000, 6.000], mean observation: 172.444 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     3482/2000000: episode: 11, duration: 9.180s, episode steps: 314, steps per second: 34, episode reward: 212.600, mean reward: 0.677 [-1.000, 1.000], mean action: 2.914 [0.000, 6.000], mean observation: 171.708 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     3789/2000000: episode: 12, duration: 8.634s, episode steps: 307, steps per second: 36, episode reward: 123.600, mean reward: 0.403 [-1.000, 0.500], mean action: 3.049 [0.000, 6.000], mean observation: 172.272 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     4064/2000000: episode: 13, duration: 7.475s, episode steps: 275, steps per second: 37, episode reward: 102.400, mean reward: 0.372 [-1.000, 0.500], mean action: 2.876 [0.000, 6.000], mean observation: 172.312 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     4378/2000000: episode: 14, duration: 9.226s, episode steps: 314, steps per second: 34, episode reward: 168.700, mean reward: 0.537 [-1.000, 1.000], mean action: 2.939 [0.000, 6.000], mean observation: 172.099 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     4690/2000000: episode: 15, duration: 8.852s, episode steps: 312, steps per second: 35, episode reward: 130.300, mean reward: 0.418 [-1.000, 1.000], mean action: 3.000 [0.000, 6.000], mean observation: 172.203 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     5038/2000000: episode: 16, duration: 10.585s, episode steps: 348, steps per second: 33, episode reward: 218.800, mean reward: 0.629 [-1.000, 1.000], mean action: 3.083 [0.000, 6.000], mean observation: 173.317 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     5311/2000000: episode: 17, duration: 7.562s, episode steps: 273, steps per second: 36, episode reward: 113.400, mean reward: 0.415 [-1.000, 0.500], mean action: 2.945 [0.000, 6.000], mean observation: 172.384 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     5627/2000000: episode: 18, duration: 9.100s, episode steps: 316, steps per second: 35, episode reward: 179.200, mean reward: 0.567 [-1.000, 1.000], mean action: 3.035 [0.000, 6.000], mean observation: 171.963 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     5910/2000000: episode: 19, duration: 7.723s, episode steps: 283, steps per second: 37, episode reward: 105.200, mean reward: 0.372 [-1.000, 0.500], mean action: 2.979 [0.000, 6.000], mean observation: 172.880 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     6220/2000000: episode: 20, duration: 8.901s, episode steps: 310, steps per second: 35, episode reward: 183.700, mean reward: 0.593 [-1.000, 1.000], mean action: 2.984 [0.000, 6.000], mean observation: 172.297 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     6531/2000000: episode: 21, duration: 8.676s, episode steps: 311, steps per second: 36, episode reward: 122.400, mean reward: 0.394 [-1.000, 0.500], mean action: 2.865 [0.000, 6.000], mean observation: 172.908 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     6818/2000000: episode: 22, duration: 7.976s, episode steps: 287, steps per second: 36, episode reward: 118.400, mean reward: 0.413 [-1.000, 0.500], mean action: 2.892 [0.000, 6.000], mean observation: 172.237 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     7125/2000000: episode: 23, duration: 8.636s, episode steps: 307, steps per second: 36, episode reward: 136.500, mean reward: 0.445 [-1.000, 1.000], mean action: 3.033 [0.000, 6.000], mean observation: 172.445 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     7394/2000000: episode: 24, duration: 7.201s, episode steps: 269, steps per second: 37, episode reward: 89.800, mean reward: 0.334 [-1.000, 0.500], mean action: 2.963 [0.000, 6.000], mean observation: 173.072 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     7703/2000000: episode: 25, duration: 8.635s, episode steps: 309, steps per second: 36, episode reward: 153.200, mean reward: 0.496 [-1.000, 1.000], mean action: 3.000 [0.000, 6.000], mean observation: 172.213 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     8016/2000000: episode: 26, duration: 8.835s, episode steps: 313, steps per second: 35, episode reward: 127.200, mean reward: 0.406 [-1.000, 1.000], mean action: 3.032 [0.000, 6.000], mean observation: 172.297 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     8330/2000000: episode: 27, duration: 9.195s, episode steps: 314, steps per second: 34, episode reward: 175.600, mean reward: 0.559 [-1.000, 1.000], mean action: 2.908 [0.000, 6.000], mean observation: 172.400 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     8605/2000000: episode: 28, duration: 7.580s, episode steps: 275, steps per second: 36, episode reward: 114.000, mean reward: 0.415 [-1.000, 0.500], mean action: 2.862 [0.000, 6.000], mean observation: 172.196 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     8903/2000000: episode: 29, duration: 8.250s, episode steps: 298, steps per second: 36, episode reward: 118.300, mean reward: 0.397 [-1.000, 0.500], mean action: 2.785 [0.000, 6.000], mean observation: 172.811 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     9224/2000000: episode: 30, duration: 9.512s, episode steps: 321, steps per second: 34, episode reward: 208.000, mean reward: 0.648 [-1.000, 1.000], mean action: 2.975 [0.000, 6.000], mean observation: 171.955 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     9553/2000000: episode: 31, duration: 10.018s, episode steps: 329, steps per second: 33, episode reward: 238.200, mean reward: 0.724 [-1.000, 1.000], mean action: 3.030 [0.000, 6.000], mean observation: 172.420 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     9896/2000000: episode: 32, duration: 10.422s, episode steps: 343, steps per second: 33, episode reward: 206.300, mean reward: 0.601 [-1.000, 1.000], mean action: 3.172 [0.000, 6.000], mean observation: 173.259 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    10208/2000000: episode: 33, duration: 8.848s, episode steps: 312, steps per second: 35, episode reward: 124.500, mean reward: 0.399 [-1.000, 0.500], mean action: 3.038 [0.000, 6.000], mean observation: 172.465 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    10518/2000000: episode: 34, duration: 8.926s, episode steps: 310, steps per second: 35, episode reward: 130.800, mean reward: 0.422 [-1.000, 1.000], mean action: 3.035 [0.000, 6.000], mean observation: 172.214 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    10788/2000000: episode: 35, duration: 7.389s, episode steps: 270, steps per second: 37, episode reward: 103.900, mean reward: 0.385 [-1.000, 0.500], mean action: 2.837 [0.000, 6.000], mean observation: 172.114 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    11064/2000000: episode: 36, duration: 7.536s, episode steps: 276, steps per second: 37, episode reward: 104.500, mean reward: 0.379 [-1.000, 0.500], mean action: 2.982 [0.000, 6.000], mean observation: 172.211 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    11379/2000000: episode: 37, duration: 9.193s, episode steps: 315, steps per second: 34, episode reward: 159.100, mean reward: 0.505 [-1.000, 1.000], mean action: 2.924 [0.000, 6.000], mean observation: 172.594 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    11642/2000000: episode: 38, duration: 7.105s, episode steps: 263, steps per second: 37, episode reward: 95.200, mean reward: 0.362 [-1.000, 0.500], mean action: 2.973 [0.000, 6.000], mean observation: 172.601 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    11944/2000000: episode: 39, duration: 8.400s, episode steps: 302, steps per second: 36, episode reward: 126.100, mean reward: 0.418 [-1.000, 1.000], mean action: 2.877 [0.000, 6.000], mean observation: 172.146 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    12296/2000000: episode: 40, duration: 10.788s, episode steps: 352, steps per second: 33, episode reward: 220.800, mean reward: 0.627 [-1.000, 1.000], mean action: 3.057 [0.000, 6.000], mean observation: 172.879 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    12624/2000000: episode: 41, duration: 9.902s, episode steps: 328, steps per second: 33, episode reward: 202.500, mean reward: 0.617 [-1.000, 1.000], mean action: 2.988 [0.000, 6.000], mean observation: 172.703 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    12967/2000000: episode: 42, duration: 10.428s, episode steps: 343, steps per second: 33, episode reward: 231.200, mean reward: 0.674 [-1.000, 1.000], mean action: 3.111 [0.000, 6.000], mean observation: 173.102 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    13278/2000000: episode: 43, duration: 8.659s, episode steps: 311, steps per second: 36, episode reward: 118.400, mean reward: 0.381 [-1.000, 0.500], mean action: 3.080 [0.000, 6.000], mean observation: 172.343 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    13600/2000000: episode: 44, duration: 9.478s, episode steps: 322, steps per second: 34, episode reward: 221.200, mean reward: 0.687 [-1.000, 1.000], mean action: 3.130 [0.000, 6.000], mean observation: 171.634 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    13925/2000000: episode: 45, duration: 9.800s, episode steps: 325, steps per second: 33, episode reward: 216.000, mean reward: 0.665 [-1.000, 1.000], mean action: 3.157 [0.000, 6.000], mean observation: 171.876 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    14241/2000000: episode: 46, duration: 9.432s, episode steps: 316, steps per second: 34, episode reward: 157.000, mean reward: 0.497 [-1.000, 1.000], mean action: 3.051 [0.000, 6.000], mean observation: 172.107 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    14552/2000000: episode: 47, duration: 8.628s, episode steps: 311, steps per second: 36, episode reward: 116.000, mean reward: 0.373 [-1.000, 0.500], mean action: 3.000 [0.000, 6.000], mean observation: 172.861 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    14870/2000000: episode: 48, duration: 9.564s, episode steps: 318, steps per second: 33, episode reward: 174.900, mean reward: 0.550 [-1.000, 1.000], mean action: 3.019 [0.000, 6.000], mean observation: 172.196 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    15179/2000000: episode: 49, duration: 8.869s, episode steps: 309, steps per second: 35, episode reward: 143.800, mean reward: 0.465 [-1.000, 1.000], mean action: 3.006 [0.000, 6.000], mean observation: 171.930 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    15486/2000000: episode: 50, duration: 8.629s, episode steps: 307, steps per second: 36, episode reward: 124.800, mean reward: 0.407 [-1.000, 0.500], mean action: 2.866 [0.000, 6.000], mean observation: 172.372 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    15835/2000000: episode: 51, duration: 10.627s, episode steps: 349, steps per second: 33, episode reward: 229.700, mean reward: 0.658 [-1.000, 1.000], mean action: 3.175 [0.000, 6.000], mean observation: 173.068 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    16147/2000000: episode: 52, duration: 8.775s, episode steps: 312, steps per second: 36, episode reward: 125.300, mean reward: 0.402 [-1.000, 0.500], mean action: 2.939 [0.000, 6.000], mean observation: 172.028 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    16493/2000000: episode: 53, duration: 10.413s, episode steps: 346, steps per second: 33, episode reward: 150.100, mean reward: 0.434 [-1.000, 1.000], mean action: 3.101 [0.000, 6.000], mean observation: 173.114 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    16816/2000000: episode: 54, duration: 9.662s, episode steps: 323, steps per second: 33, episode reward: 146.400, mean reward: 0.453 [-1.000, 0.500], mean action: 3.093 [0.000, 6.000], mean observation: 172.519 [20.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    17128/2000000: episode: 55, duration: 8.864s, episode steps: 312, steps per second: 35, episode reward: 181.200, mean reward: 0.581 [-1.000, 1.000], mean action: 3.006 [0.000, 6.000], mean observation: 171.271 [21.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    17393/2000000: episode: 56, duration: 7.083s, episode steps: 265, steps per second: 37, episode reward: 93.400, mean reward: 0.352 [-1.000, 0.500], mean action: 2.883 [0.000, 6.000], mean observation: 172.383 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    17708/2000000: episode: 57, duration: 9.075s, episode steps: 315, steps per second: 35, episode reward: 140.100, mean reward: 0.445 [-1.000, 1.000], mean action: 2.933 [0.000, 6.000], mean observation: 171.637 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    18045/2000000: episode: 58, duration: 10.165s, episode steps: 337, steps per second: 33, episode reward: 213.200, mean reward: 0.633 [-1.000, 1.000], mean action: 3.184 [0.000, 6.000], mean observation: 172.440 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    18411/2000000: episode: 59, duration: 11.280s, episode steps: 366, steps per second: 32, episode reward: 231.800, mean reward: 0.633 [-1.000, 1.000], mean action: 3.186 [0.000, 6.000], mean observation: 172.578 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    18757/2000000: episode: 60, duration: 10.564s, episode steps: 346, steps per second: 33, episode reward: 252.900, mean reward: 0.731 [-1.000, 1.000], mean action: 3.072 [0.000, 6.000], mean observation: 172.547 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    19089/2000000: episode: 61, duration: 10.095s, episode steps: 332, steps per second: 33, episode reward: 220.200, mean reward: 0.663 [-1.000, 1.000], mean action: 3.057 [0.000, 6.000], mean observation: 172.107 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    19403/2000000: episode: 62, duration: 9.268s, episode steps: 314, steps per second: 34, episode reward: 136.400, mean reward: 0.434 [-1.000, 1.000], mean action: 3.051 [0.000, 6.000], mean observation: 171.598 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    19712/2000000: episode: 63, duration: 8.956s, episode steps: 309, steps per second: 35, episode reward: 148.900, mean reward: 0.482 [-1.000, 1.000], mean action: 2.858 [0.000, 6.000], mean observation: 171.428 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    20018/2000000: episode: 64, duration: 8.620s, episode steps: 306, steps per second: 35, episode reward: 125.700, mean reward: 0.411 [-1.000, 1.000], mean action: 3.059 [0.000, 6.000], mean observation: 171.665 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    20316/2000000: episode: 65, duration: 8.256s, episode steps: 298, steps per second: 36, episode reward: 120.300, mean reward: 0.404 [-1.000, 0.500], mean action: 2.936 [0.000, 6.000], mean observation: 171.736 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    20634/2000000: episode: 66, duration: 9.394s, episode steps: 318, steps per second: 34, episode reward: 225.300, mean reward: 0.708 [-1.000, 1.000], mean action: 3.063 [0.000, 6.000], mean observation: 171.244 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    20928/2000000: episode: 67, duration: 8.183s, episode steps: 294, steps per second: 36, episode reward: 123.600, mean reward: 0.420 [-1.000, 1.000], mean action: 2.891 [0.000, 6.000], mean observation: 171.191 [21.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    21271/2000000: episode: 68, duration: 10.410s, episode steps: 343, steps per second: 33, episode reward: 243.300, mean reward: 0.709 [-1.000, 1.000], mean action: 3.140 [0.000, 6.000], mean observation: 172.607 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    21583/2000000: episode: 69, duration: 9.106s, episode steps: 312, steps per second: 34, episode reward: 138.300, mean reward: 0.443 [-1.000, 1.000], mean action: 2.974 [0.000, 6.000], mean observation: 171.509 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    21931/2000000: episode: 70, duration: 10.670s, episode steps: 348, steps per second: 33, episode reward: 218.000, mean reward: 0.626 [-1.000, 1.000], mean action: 3.175 [0.000, 6.000], mean observation: 172.056 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    22245/2000000: episode: 71, duration: 9.040s, episode steps: 314, steps per second: 35, episode reward: 198.600, mean reward: 0.632 [-1.000, 1.000], mean action: 3.054 [0.000, 6.000], mean observation: 170.624 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    22561/2000000: episode: 72, duration: 9.218s, episode steps: 316, steps per second: 34, episode reward: 194.100, mean reward: 0.614 [-1.000, 1.000], mean action: 2.959 [0.000, 6.000], mean observation: 170.901 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    22885/2000000: episode: 73, duration: 9.739s, episode steps: 324, steps per second: 33, episode reward: 218.000, mean reward: 0.673 [-1.000, 1.000], mean action: 3.111 [0.000, 6.000], mean observation: 171.033 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    23197/2000000: episode: 74, duration: 9.107s, episode steps: 312, steps per second: 34, episode reward: 129.700, mean reward: 0.416 [-1.000, 0.500], mean action: 3.080 [0.000, 6.000], mean observation: 171.212 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    23493/2000000: episode: 75, duration: 8.305s, episode steps: 296, steps per second: 36, episode reward: 121.300, mean reward: 0.410 [-1.000, 0.500], mean action: 2.889 [0.000, 6.000], mean observation: 171.197 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    23801/2000000: episode: 76, duration: 8.788s, episode steps: 308, steps per second: 35, episode reward: 131.000, mean reward: 0.425 [-1.000, 1.000], mean action: 3.042 [0.000, 6.000], mean observation: 171.047 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    24090/2000000: episode: 77, duration: 8.028s, episode steps: 289, steps per second: 36, episode reward: 120.600, mean reward: 0.417 [-1.000, 0.500], mean action: 2.837 [0.000, 6.000], mean observation: 170.951 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    24400/2000000: episode: 78, duration: 8.927s, episode steps: 310, steps per second: 35, episode reward: 138.600, mean reward: 0.447 [-1.000, 1.000], mean action: 3.029 [0.000, 6.000], mean observation: 171.316 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    24702/2000000: episode: 79, duration: 8.441s, episode steps: 302, steps per second: 36, episode reward: 124.300, mean reward: 0.412 [-1.000, 0.500], mean action: 2.897 [0.000, 6.000], mean observation: 171.463 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    25001/2000000: episode: 80, duration: 8.830s, episode steps: 299, steps per second: 34, episode reward: 125.200, mean reward: 0.419 [-1.000, 0.500], mean action: 2.940 [0.000, 6.000], mean observation: 171.278 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    25241/2000000: episode: 81, duration: 6.369s, episode steps: 240, steps per second: 38, episode reward: 81.700, mean reward: 0.340 [-1.000, 0.500], mean action: 2.746 [0.000, 6.000], mean observation: 172.160 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    25561/2000000: episode: 82, duration: 9.166s, episode steps: 320, steps per second: 35, episode reward: 114.500, mean reward: 0.358 [-1.000, 0.500], mean action: 3.091 [0.000, 6.000], mean observation: 171.853 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    25908/2000000: episode: 83, duration: 10.611s, episode steps: 347, steps per second: 33, episode reward: 215.300, mean reward: 0.620 [-1.000, 1.000], mean action: 3.130 [0.000, 6.000], mean observation: 172.032 [21.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    26214/2000000: episode: 84, duration: 8.751s, episode steps: 306, steps per second: 35, episode reward: 140.000, mean reward: 0.458 [-1.000, 1.000], mean action: 2.974 [0.000, 6.000], mean observation: 171.106 [20.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    26574/2000000: episode: 85, duration: 11.024s, episode steps: 360, steps per second: 33, episode reward: 241.300, mean reward: 0.670 [-1.000, 1.000], mean action: 2.992 [0.000, 6.000], mean observation: 172.222 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    26885/2000000: episode: 86, duration: 9.006s, episode steps: 311, steps per second: 35, episode reward: 136.400, mean reward: 0.439 [-1.000, 1.000], mean action: 2.920 [0.000, 6.000], mean observation: 171.129 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    27192/2000000: episode: 87, duration: 8.803s, episode steps: 307, steps per second: 35, episode reward: 129.600, mean reward: 0.422 [-1.000, 0.500], mean action: 3.007 [0.000, 6.000], mean observation: 171.454 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    27501/2000000: episode: 88, duration: 8.647s, episode steps: 309, steps per second: 36, episode reward: 126.200, mean reward: 0.408 [-1.000, 0.500], mean action: 2.812 [0.000, 6.000], mean observation: 172.000 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    27813/2000000: episode: 89, duration: 8.872s, episode steps: 312, steps per second: 35, episode reward: 119.300, mean reward: 0.382 [-1.000, 0.500], mean action: 3.016 [0.000, 6.000], mean observation: 171.588 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    28119/2000000: episode: 90, duration: 8.757s, episode steps: 306, steps per second: 35, episode reward: 126.300, mean reward: 0.413 [-1.000, 0.500], mean action: 2.967 [0.000, 6.000], mean observation: 171.606 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    28451/2000000: episode: 91, duration: 10.070s, episode steps: 332, steps per second: 33, episode reward: 230.900, mean reward: 0.695 [-1.000, 1.000], mean action: 2.985 [0.000, 6.000], mean observation: 171.471 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    28762/2000000: episode: 92, duration: 9.022s, episode steps: 311, steps per second: 34, episode reward: 137.500, mean reward: 0.442 [-1.000, 1.000], mean action: 3.010 [0.000, 6.000], mean observation: 171.379 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    29036/2000000: episode: 93, duration: 7.547s, episode steps: 274, steps per second: 36, episode reward: 112.300, mean reward: 0.410 [-1.000, 0.500], mean action: 2.865 [0.000, 6.000], mean observation: 171.371 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    29333/2000000: episode: 94, duration: 8.304s, episode steps: 297, steps per second: 36, episode reward: 123.400, mean reward: 0.415 [-1.000, 0.500], mean action: 2.960 [0.000, 6.000], mean observation: 171.857 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    29653/2000000: episode: 95, duration: 9.523s, episode steps: 320, steps per second: 34, episode reward: 145.700, mean reward: 0.455 [-1.000, 0.500], mean action: 2.956 [0.000, 6.000], mean observation: 172.107 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    29981/2000000: episode: 96, duration: 9.837s, episode steps: 328, steps per second: 33, episode reward: 158.500, mean reward: 0.483 [-1.000, 1.000], mean action: 3.247 [0.000, 6.000], mean observation: 171.700 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    30328/2000000: episode: 97, duration: 10.598s, episode steps: 347, steps per second: 33, episode reward: 220.800, mean reward: 0.636 [-1.000, 1.000], mean action: 3.052 [0.000, 6.000], mean observation: 172.451 [21.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    30652/2000000: episode: 98, duration: 9.805s, episode steps: 324, steps per second: 33, episode reward: 164.700, mean reward: 0.508 [-1.000, 1.000], mean action: 3.117 [0.000, 6.000], mean observation: 172.015 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    30962/2000000: episode: 99, duration: 9.037s, episode steps: 310, steps per second: 34, episode reward: 180.500, mean reward: 0.582 [-1.000, 1.000], mean action: 2.977 [0.000, 6.000], mean observation: 171.553 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    31273/2000000: episode: 100, duration: 8.936s, episode steps: 311, steps per second: 35, episode reward: 141.800, mean reward: 0.456 [-1.000, 1.000], mean action: 3.084 [0.000, 6.000], mean observation: 171.695 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    31544/2000000: episode: 101, duration: 7.405s, episode steps: 271, steps per second: 37, episode reward: 106.400, mean reward: 0.393 [-1.000, 0.500], mean action: 2.771 [0.000, 6.000], mean observation: 172.054 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    31911/2000000: episode: 102, duration: 11.348s, episode steps: 367, steps per second: 32, episode reward: 207.400, mean reward: 0.565 [-1.000, 1.000], mean action: 3.139 [0.000, 6.000], mean observation: 172.205 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    32262/2000000: episode: 103, duration: 10.713s, episode steps: 351, steps per second: 33, episode reward: 216.600, mean reward: 0.617 [-1.000, 1.000], mean action: 3.123 [0.000, 6.000], mean observation: 172.823 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    32580/2000000: episode: 104, duration: 9.506s, episode steps: 318, steps per second: 33, episode reward: 152.100, mean reward: 0.478 [-1.000, 1.000], mean action: 3.107 [0.000, 6.000], mean observation: 172.152 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    32894/2000000: episode: 105, duration: 9.109s, episode steps: 314, steps per second: 34, episode reward: 147.400, mean reward: 0.469 [-1.000, 1.000], mean action: 3.099 [0.000, 6.000], mean observation: 172.204 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    33219/2000000: episode: 106, duration: 9.776s, episode steps: 325, steps per second: 33, episode reward: 201.800, mean reward: 0.621 [-1.000, 1.000], mean action: 2.969 [0.000, 6.000], mean observation: 172.455 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    33540/2000000: episode: 107, duration: 9.527s, episode steps: 321, steps per second: 34, episode reward: 203.200, mean reward: 0.633 [-1.000, 1.000], mean action: 2.907 [0.000, 6.000], mean observation: 172.273 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    33851/2000000: episode: 108, duration: 9.081s, episode steps: 311, steps per second: 34, episode reward: 151.300, mean reward: 0.486 [-1.000, 1.000], mean action: 3.039 [0.000, 6.000], mean observation: 172.044 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    34187/2000000: episode: 109, duration: 10.069s, episode steps: 336, steps per second: 33, episode reward: 164.600, mean reward: 0.490 [-1.000, 1.000], mean action: 3.089 [0.000, 6.000], mean observation: 173.126 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    34514/2000000: episode: 110, duration: 9.765s, episode steps: 327, steps per second: 33, episode reward: 221.200, mean reward: 0.676 [-1.000, 1.000], mean action: 3.067 [0.000, 6.000], mean observation: 172.214 [22.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    34826/2000000: episode: 111, duration: 9.134s, episode steps: 312, steps per second: 34, episode reward: 151.600, mean reward: 0.486 [-1.000, 1.000], mean action: 3.045 [0.000, 6.000], mean observation: 172.433 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    35139/2000000: episode: 112, duration: 9.031s, episode steps: 313, steps per second: 35, episode reward: 139.600, mean reward: 0.446 [-1.000, 1.000], mean action: 3.000 [0.000, 6.000], mean observation: 172.085 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    35459/2000000: episode: 113, duration: 9.497s, episode steps: 320, steps per second: 34, episode reward: 176.500, mean reward: 0.552 [-1.000, 1.000], mean action: 3.056 [0.000, 6.000], mean observation: 172.620 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    35767/2000000: episode: 114, duration: 8.850s, episode steps: 308, steps per second: 35, episode reward: 184.100, mean reward: 0.598 [-1.000, 1.000], mean action: 2.903 [0.000, 6.000], mean observation: 171.978 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    36089/2000000: episode: 115, duration: 9.508s, episode steps: 322, steps per second: 34, episode reward: 215.600, mean reward: 0.670 [-1.000, 1.000], mean action: 2.891 [0.000, 6.000], mean observation: 172.093 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    36397/2000000: episode: 116, duration: 8.639s, episode steps: 308, steps per second: 36, episode reward: 131.100, mean reward: 0.426 [-1.000, 1.000], mean action: 2.890 [0.000, 6.000], mean observation: 172.181 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    36727/2000000: episode: 117, duration: 9.992s, episode steps: 330, steps per second: 33, episode reward: 234.800, mean reward: 0.712 [-1.000, 1.000], mean action: 3.067 [0.000, 6.000], mean observation: 172.238 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    37011/2000000: episode: 118, duration: 7.832s, episode steps: 284, steps per second: 36, episode reward: 115.700, mean reward: 0.407 [-1.000, 0.500], mean action: 2.796 [0.000, 6.000], mean observation: 172.408 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    37355/2000000: episode: 119, duration: 10.399s, episode steps: 344, steps per second: 33, episode reward: 227.200, mean reward: 0.660 [-1.000, 1.000], mean action: 3.102 [0.000, 6.000], mean observation: 173.275 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    37677/2000000: episode: 120, duration: 9.524s, episode steps: 322, steps per second: 34, episode reward: 212.300, mean reward: 0.659 [-1.000, 1.000], mean action: 2.997 [0.000, 6.000], mean observation: 172.217 [21.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    38029/2000000: episode: 121, duration: 10.754s, episode steps: 352, steps per second: 33, episode reward: 235.600, mean reward: 0.669 [-1.000, 1.000], mean action: 3.264 [0.000, 6.000], mean observation: 172.859 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    38302/2000000: episode: 122, duration: 7.543s, episode steps: 273, steps per second: 36, episode reward: 113.000, mean reward: 0.414 [-1.000, 0.500], mean action: 2.868 [0.000, 6.000], mean observation: 172.349 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    38618/2000000: episode: 123, duration: 9.320s, episode steps: 316, steps per second: 34, episode reward: 189.300, mean reward: 0.599 [-1.000, 1.000], mean action: 3.054 [0.000, 6.000], mean observation: 172.097 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    38929/2000000: episode: 124, duration: 8.791s, episode steps: 311, steps per second: 35, episode reward: 124.800, mean reward: 0.401 [-1.000, 0.500], mean action: 2.936 [0.000, 6.000], mean observation: 172.566 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    39243/2000000: episode: 125, duration: 9.123s, episode steps: 314, steps per second: 34, episode reward: 173.700, mean reward: 0.553 [-1.000, 1.000], mean action: 3.038 [0.000, 6.000], mean observation: 171.953 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    39584/2000000: episode: 126, duration: 10.307s, episode steps: 341, steps per second: 33, episode reward: 237.600, mean reward: 0.697 [-1.000, 1.000], mean action: 3.029 [0.000, 6.000], mean observation: 173.325 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    39896/2000000: episode: 127, duration: 8.955s, episode steps: 312, steps per second: 35, episode reward: 208.100, mean reward: 0.667 [-1.000, 1.000], mean action: 2.997 [0.000, 6.000], mean observation: 171.667 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    40242/2000000: episode: 128, duration: 10.612s, episode steps: 346, steps per second: 33, episode reward: 242.500, mean reward: 0.701 [-1.000, 1.000], mean action: 3.121 [0.000, 6.000], mean observation: 172.654 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    40555/2000000: episode: 129, duration: 9.061s, episode steps: 313, steps per second: 35, episode reward: 184.800, mean reward: 0.590 [-1.000, 1.000], mean action: 3.045 [0.000, 6.000], mean observation: 171.726 [21.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    40874/2000000: episode: 130, duration: 9.478s, episode steps: 319, steps per second: 34, episode reward: 210.000, mean reward: 0.658 [-1.000, 1.000], mean action: 3.066 [0.000, 6.000], mean observation: 171.994 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    41219/2000000: episode: 131, duration: 10.526s, episode steps: 345, steps per second: 33, episode reward: 232.000, mean reward: 0.672 [-1.000, 1.000], mean action: 3.113 [0.000, 6.000], mean observation: 173.171 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    41529/2000000: episode: 132, duration: 8.890s, episode steps: 310, steps per second: 35, episode reward: 200.800, mean reward: 0.648 [-1.000, 1.000], mean action: 2.852 [0.000, 6.000], mean observation: 171.476 [25.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    41875/2000000: episode: 133, duration: 10.531s, episode steps: 346, steps per second: 33, episode reward: 245.100, mean reward: 0.708 [-1.000, 1.000], mean action: 3.179 [0.000, 6.000], mean observation: 172.954 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    42185/2000000: episode: 134, duration: 8.773s, episode steps: 310, steps per second: 35, episode reward: 123.100, mean reward: 0.397 [-1.000, 0.500], mean action: 2.942 [0.000, 6.000], mean observation: 172.085 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    42575/2000000: episode: 135, duration: 12.197s, episode steps: 390, steps per second: 32, episode reward: 213.100, mean reward: 0.546 [-1.000, 1.000], mean action: 3.251 [0.000, 6.000], mean observation: 172.960 [23.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    42903/2000000: episode: 136, duration: 9.910s, episode steps: 328, steps per second: 33, episode reward: 203.900, mean reward: 0.622 [-1.000, 1.000], mean action: 2.927 [0.000, 6.000], mean observation: 172.520 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    43220/2000000: episode: 137, duration: 9.258s, episode steps: 317, steps per second: 34, episode reward: 195.200, mean reward: 0.616 [-1.000, 1.000], mean action: 3.054 [0.000, 6.000], mean observation: 171.427 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    43587/2000000: episode: 138, duration: 11.347s, episode steps: 367, steps per second: 32, episode reward: 216.900, mean reward: 0.591 [-1.000, 1.000], mean action: 3.071 [0.000, 6.000], mean observation: 172.719 [24.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
# ...
#  1290553/2000000: episode: 3992, duration: 20.480s, episode steps: 471, steps per second: 23, episode reward: 440.000, mean reward: 0.934 [0.500, 1.000], mean action: 3.580 [0.000, 6.000], mean observation: 166.132 [2.000, 255.000], loss: 0.076431, mean_absolute_error: 50.656115, mean_q: 59.212646, mean_eps: 0.100000
#  1291026/2000000: episode: 3993, duration: 20.472s, episode steps: 473, steps per second: 23, episode reward: 446.500, mean reward: 0.944 [0.500, 1.000], mean action: 3.641 [0.000, 6.000], mean observation: 166.044 [3.000, 255.000], loss: 0.071300, mean_absolute_error: 51.075503, mean_q: 59.712298, mean_eps: 0.100000
#  1291496/2000000: episode: 3994, duration: 20.521s, episode steps: 470, steps per second: 23, episode reward: 428.000, mean reward: 0.911 [0.500, 1.000], mean action: 3.747 [0.000, 6.000], mean observation: 166.051 [0.000, 255.000], loss: 0.083324, mean_absolute_error: 50.707730, mean_q: 59.278609, mean_eps: 0.100000
#  1291973/2000000: episode: 3995, duration: 20.739s, episode steps: 477, steps per second: 23, episode reward: 376.000, mean reward: 0.788 [0.500, 1.000], mean action: 3.696 [0.000, 6.000], mean observation: 164.711 [0.000, 255.000], loss: 0.071884, mean_absolute_error: 50.410776, mean_q: 58.924902, mean_eps: 0.100000
#  1292438/2000000: episode: 3996, duration: 20.406s, episode steps: 465, steps per second: 23, episode reward: 388.300, mean reward: 0.835 [-1.000, 1.000], mean action: 3.665 [0.000, 6.000], mean observation: 164.797 [0.000, 255.000], loss: 0.076366, mean_absolute_error: 50.787837, mean_q: 59.372720, mean_eps: 0.100000
#  1292903/2000000: episode: 3997, duration: 20.454s, episode steps: 465, steps per second: 23, episode reward: 439.500, mean reward: 0.945 [0.500, 1.000], mean action: 3.447 [0.000, 6.000], mean observation: 166.365 [16.000, 255.000], loss: 0.074391, mean_absolute_error: 50.534020, mean_q: 59.065809, mean_eps: 0.100000
#  1293375/2000000: episode: 3998, duration: 20.544s, episode steps: 472, steps per second: 23, episode reward: 412.200, mean reward: 0.873 [0.100, 1.000], mean action: 3.636 [0.000, 6.000], mean observation: 164.833 [0.000, 255.000], loss: 0.080176, mean_absolute_error: 50.730732, mean_q: 59.305881, mean_eps: 0.100000
#  1293843/2000000: episode: 3999, duration: 20.558s, episode steps: 468, steps per second: 23, episode reward: 430.500, mean reward: 0.920 [0.500, 1.000], mean action: 3.440 [0.000, 6.000], mean observation: 166.331 [15.000, 255.000], loss: 0.084093, mean_absolute_error: 50.761668, mean_q: 59.345930, mean_eps: 0.100000
#  1294313/2000000: episode: 4000, duration: 20.617s, episode steps: 470, steps per second: 23, episode reward: 393.800, mean reward: 0.838 [0.100, 1.000], mean action: 3.428 [0.000, 6.000], mean observation: 164.924 [0.000, 255.000], loss: 0.076291, mean_absolute_error: 50.588048, mean_q: 59.131307, mean_eps: 0.100000
#  1294787/2000000: episode: 4001, duration: 20.468s, episode steps: 474, steps per second: 23, episode reward: 442.000, mean reward: 0.932 [0.500, 1.000], mean action: 3.675 [0.000, 6.000], mean observation: 166.803 [24.000, 255.000], loss: 0.067950, mean_absolute_error: 51.105948, mean_q: 59.744160, mean_eps: 0.100000
#  1295259/2000000: episode: 4002, duration: 20.408s, episode steps: 472, steps per second: 23, episode reward: 443.000, mean reward: 0.939 [0.500, 1.000], mean action: 3.653 [0.000, 6.000], mean observation: 166.512 [22.000, 255.000], loss: 0.075642, mean_absolute_error: 50.891255, mean_q: 59.509950, mean_eps: 0.100000
#  1295753/2000000: episode: 4003, duration: 21.385s, episode steps: 494, steps per second: 23, episode reward: 395.500, mean reward: 0.801 [-1.000, 1.000], mean action: 3.500 [0.000, 6.000], mean observation: 162.762 [0.000, 255.000], loss: 0.074581, mean_absolute_error: 50.954135, mean_q: 59.568649, mean_eps: 0.100000
#  1296225/2000000: episode: 4004, duration: 20.648s, episode steps: 472, steps per second: 23, episode reward: 419.000, mean reward: 0.888 [0.500, 1.000], mean action: 3.481 [0.000, 6.000], mean observation: 165.205 [0.000, 255.000], loss: 0.077291, mean_absolute_error: 50.617982, mean_q: 59.160333, mean_eps: 0.100000
#  1296699/2000000: episode: 4005, duration: 20.571s, episode steps: 474, steps per second: 23, episode reward: 429.500, mean reward: 0.906 [0.500, 1.000], mean action: 3.635 [0.000, 6.000], mean observation: 166.150 [17.000, 255.000], loss: 0.075583, mean_absolute_error: 50.689100, mean_q: 59.257585, mean_eps: 0.100000
#  1297182/2000000: episode: 4006, duration: 20.651s, episode steps: 483, steps per second: 23, episode reward: 384.000, mean reward: 0.795 [0.500, 1.000], mean action: 3.325 [0.000, 6.000], mean observation: 165.925 [24.000, 255.000], loss: 0.078596, mean_absolute_error: 50.544540, mean_q: 59.104168, mean_eps: 0.100000
#  1297654/2000000: episode: 4007, duration: 20.406s, episode steps: 472, steps per second: 23, episode reward: 435.000, mean reward: 0.922 [0.500, 1.000], mean action: 3.504 [0.000, 6.000], mean observation: 166.537 [23.000, 255.000], loss: 0.080055, mean_absolute_error: 50.713571, mean_q: 59.303937, mean_eps: 0.100000
#  1298128/2000000: episode: 4008, duration: 20.632s, episode steps: 474, steps per second: 23, episode reward: 421.500, mean reward: 0.889 [0.500, 1.000], mean action: 3.435 [0.000, 6.000], mean observation: 166.166 [16.000, 255.000], loss: 0.080359, mean_absolute_error: 50.615182, mean_q: 59.193546, mean_eps: 0.100000
#  1298608/2000000: episode: 4009, duration: 20.561s, episode steps: 480, steps per second: 23, episode reward: 371.100, mean reward: 0.773 [0.100, 1.000], mean action: 3.621 [0.000, 6.000], mean observation: 165.823 [0.000, 255.000], loss: 0.078078, mean_absolute_error: 50.689906, mean_q: 59.281361, mean_eps: 0.100000
#  1299079/2000000: episode: 4010, duration: 20.539s, episode steps: 471, steps per second: 23, episode reward: 413.000, mean reward: 0.877 [0.500, 1.000], mean action: 3.711 [0.000, 6.000], mean observation: 165.853 [13.000, 255.000], loss: 0.083956, mean_absolute_error: 50.621022, mean_q: 59.180341, mean_eps: 0.100000
#  1299550/2000000: episode: 4011, duration: 20.527s, episode steps: 471, steps per second: 23, episode reward: 441.500, mean reward: 0.937 [0.500, 1.000], mean action: 3.499 [0.000, 6.000], mean observation: 165.836 [17.000, 255.000], loss: 0.075518, mean_absolute_error: 50.587736, mean_q: 59.129555, mean_eps: 0.100000
#  1300023/2000000: episode: 4012, duration: 20.486s, episode steps: 473, steps per second: 23, episode reward: 416.000, mean reward: 0.879 [0.500, 1.000], mean action: 3.562 [0.000, 6.000], mean observation: 165.216 [1.000, 255.000], loss: 0.076337, mean_absolute_error: 50.933085, mean_q: 59.533292, mean_eps: 0.100000
#  1300493/2000000: episode: 4013, duration: 20.599s, episode steps: 470, steps per second: 23, episode reward: 435.000, mean reward: 0.926 [0.500, 1.000], mean action: 3.534 [0.000, 6.000], mean observation: 165.997 [20.000, 255.000], loss: 0.080927, mean_absolute_error: 50.849496, mean_q: 59.449596, mean_eps: 0.100000
#  1300969/2000000: episode: 4014, duration: 20.574s, episode steps: 476, steps per second: 23, episode reward: 429.000, mean reward: 0.901 [0.500, 1.000], mean action: 3.630 [0.000, 6.000], mean observation: 164.765 [0.000, 255.000], loss: 0.084533, mean_absolute_error: 51.115106, mean_q: 59.758048, mean_eps: 0.100000
#  1301426/2000000: episode: 4015, duration: 20.523s, episode steps: 457, steps per second: 22, episode reward: 420.000, mean reward: 0.919 [0.500, 1.000], mean action: 3.604 [0.000, 6.000], mean observation: 165.883 [16.000, 255.000], loss: 0.083081, mean_absolute_error: 50.849968, mean_q: 59.459000, mean_eps: 0.100000
#  1301893/2000000: episode: 4016, duration: 20.515s, episode steps: 467, steps per second: 23, episode reward: 422.000, mean reward: 0.904 [0.500, 1.000], mean action: 3.582 [0.000, 6.000], mean observation: 165.733 [4.000, 255.000], loss: 0.075311, mean_absolute_error: 51.301068, mean_q: 59.962677, mean_eps: 0.100000
#  1302366/2000000: episode: 4017, duration: 20.479s, episode steps: 473, steps per second: 23, episode reward: 444.000, mean reward: 0.939 [0.500, 1.000], mean action: 3.461 [0.000, 6.000], mean observation: 165.372 [7.000, 255.000], loss: 0.080225, mean_absolute_error: 51.081100, mean_q: 59.705678, mean_eps: 0.100000
#  1302843/2000000: episode: 4018, duration: 20.512s, episode steps: 477, steps per second: 23, episode reward: 426.500, mean reward: 0.894 [0.500, 1.000], mean action: 3.570 [0.000, 6.000], mean observation: 165.702 [17.000, 255.000], loss: 0.078483, mean_absolute_error: 51.109195, mean_q: 59.746571, mean_eps: 0.100000
#  1303313/2000000: episode: 4019, duration: 20.487s, episode steps: 470, steps per second: 23, episode reward: 442.500, mean reward: 0.941 [0.500, 1.000], mean action: 3.732 [0.000, 6.000], mean observation: 165.624 [0.000, 255.000], loss: 0.072810, mean_absolute_error: 50.793060, mean_q: 59.382262, mean_eps: 0.100000
#  1303780/2000000: episode: 4020, duration: 20.465s, episode steps: 467, steps per second: 23, episode reward: 424.000, mean reward: 0.908 [0.500, 1.000], mean action: 3.779 [0.000, 6.000], mean observation: 165.371 [0.000, 255.000], loss: 0.084180, mean_absolute_error: 51.167999, mean_q: 59.811348, mean_eps: 0.100000
#  1304257/2000000: episode: 4021, duration: 20.576s, episode steps: 477, steps per second: 23, episode reward: 421.500, mean reward: 0.884 [0.500, 1.000], mean action: 3.474 [0.000, 6.000], mean observation: 165.249 [0.000, 255.000], loss: 0.079688, mean_absolute_error: 51.113109, mean_q: 59.747233, mean_eps: 0.100000
#  1304734/2000000: episode: 4022, duration: 20.606s, episode steps: 477, steps per second: 23, episode reward: 425.500, mean reward: 0.892 [0.500, 1.000], mean action: 3.597 [0.000, 6.000], mean observation: 164.399 [0.000, 255.000], loss: 0.084312, mean_absolute_error: 51.131004, mean_q: 59.777623, mean_eps: 0.100000
#  1305207/2000000: episode: 4023, duration: 20.505s, episode steps: 473, steps per second: 23, episode reward: 411.500, mean reward: 0.870 [0.500, 1.000], mean action: 3.469 [0.000, 6.000], mean observation: 165.625 [0.000, 255.000], loss: 0.083548, mean_absolute_error: 50.969467, mean_q: 59.584842, mean_eps: 0.100000
#  1305686/2000000: episode: 4024, duration: 20.537s, episode steps: 479, steps per second: 23, episode reward: 438.000, mean reward: 0.914 [0.500, 1.000], mean action: 3.704 [0.000, 6.000], mean observation: 165.082 [0.000, 255.000], loss: 0.078846, mean_absolute_error: 50.975113, mean_q: 59.591432, mean_eps: 0.100000
#  1306159/2000000: episode: 4025, duration: 20.498s, episode steps: 473, steps per second: 23, episode reward: 426.500, mean reward: 0.902 [0.500, 1.000], mean action: 3.539 [0.000, 6.000], mean observation: 165.269 [0.000, 255.000], loss: 0.072235, mean_absolute_error: 50.674950, mean_q: 59.243211, mean_eps: 0.100000
#  1306636/2000000: episode: 4026, duration: 20.641s, episode steps: 477, steps per second: 23, episode reward: 407.000, mean reward: 0.853 [0.500, 1.000], mean action: 3.577 [0.000, 6.000], mean observation: 165.128 [0.000, 255.000], loss: 0.080329, mean_absolute_error: 51.103664, mean_q: 59.731276, mean_eps: 0.100000
#  1307110/2000000: episode: 4027, duration: 20.520s, episode steps: 474, steps per second: 23, episode reward: 425.500, mean reward: 0.898 [0.500, 1.000], mean action: 3.589 [0.000, 6.000], mean observation: 165.110 [0.000, 255.000], loss: 0.080802, mean_absolute_error: 50.909443, mean_q: 59.500579, mean_eps: 0.100000
#  1307582/2000000: episode: 4028, duration: 20.560s, episode steps: 472, steps per second: 23, episode reward: 416.000, mean reward: 0.881 [0.500, 1.000], mean action: 3.551 [0.000, 6.000], mean observation: 166.303 [22.000, 255.000], loss: 0.072467, mean_absolute_error: 51.090896, mean_q: 59.728406, mean_eps: 0.100000
#  1308054/2000000: episode: 4029, duration: 20.503s, episode steps: 472, steps per second: 23, episode reward: 409.500, mean reward: 0.868 [0.500, 1.000], mean action: 3.485 [0.000, 6.000], mean observation: 166.069 [20.000, 255.000], loss: 0.080260, mean_absolute_error: 51.274309, mean_q: 59.939891, mean_eps: 0.100000
#  1308529/2000000: episode: 4030, duration: 20.562s, episode steps: 475, steps per second: 23, episode reward: 429.500, mean reward: 0.904 [0.500, 1.000], mean action: 3.642 [0.000, 6.000], mean observation: 166.368 [19.000, 255.000], loss: 0.082918, mean_absolute_error: 50.774393, mean_q: 59.348167, mean_eps: 0.100000
#  1308998/2000000: episode: 4031, duration: 20.492s, episode steps: 469, steps per second: 23, episode reward: 441.000, mean reward: 0.940 [0.500, 1.000], mean action: 3.563 [0.000, 6.000], mean observation: 165.941 [19.000, 255.000], loss: 0.073312, mean_absolute_error: 50.950610, mean_q: 59.573823, mean_eps: 0.100000
#  1309474/2000000: episode: 4032, duration: 20.548s, episode steps: 476, steps per second: 23, episode reward: 425.500, mean reward: 0.894 [0.500, 1.000], mean action: 3.529 [0.000, 6.000], mean observation: 165.859 [13.000, 255.000], loss: 0.076377, mean_absolute_error: 50.866660, mean_q: 59.482684, mean_eps: 0.100000
#  1309945/2000000: episode: 4033, duration: 20.524s, episode steps: 471, steps per second: 23, episode reward: 432.000, mean reward: 0.917 [0.500, 1.000], mean action: 3.682 [0.000, 6.000], mean observation: 166.180 [18.000, 255.000], loss: 0.075010, mean_absolute_error: 51.104857, mean_q: 59.754572, mean_eps: 0.100000
#  1310417/2000000: episode: 4034, duration: 20.524s, episode steps: 472, steps per second: 23, episode reward: 439.000, mean reward: 0.930 [0.500, 1.000], mean action: 3.487 [0.000, 6.000], mean observation: 166.046 [17.000, 255.000], loss: 0.085601, mean_absolute_error: 51.528969, mean_q: 60.241542, mean_eps: 0.100000
#  1310894/2000000: episode: 4035, duration: 20.443s, episode steps: 477, steps per second: 23, episode reward: 440.000, mean reward: 0.922 [0.500, 1.000], mean action: 3.730 [0.000, 6.000], mean observation: 166.481 [18.000, 255.000], loss: 0.085827, mean_absolute_error: 51.337396, mean_q: 60.014286, mean_eps: 0.100000
#  1311362/2000000: episode: 4036, duration: 20.464s, episode steps: 468, steps per second: 23, episode reward: 435.500, mean reward: 0.931 [0.500, 1.000], mean action: 3.564 [0.000, 6.000], mean observation: 166.052 [13.000, 255.000], loss: 0.088307, mean_absolute_error: 51.156361, mean_q: 59.811875, mean_eps: 0.100000
#  1311832/2000000: episode: 4037, duration: 20.512s, episode steps: 470, steps per second: 23, episode reward: 441.000, mean reward: 0.938 [0.500, 1.000], mean action: 3.457 [0.000, 6.000], mean observation: 166.153 [25.000, 255.000], loss: 0.076720, mean_absolute_error: 51.191918, mean_q: 59.851034, mean_eps: 0.100000
#  1312310/2000000: episode: 4038, duration: 20.502s, episode steps: 478, steps per second: 23, episode reward: 434.500, mean reward: 0.909 [0.500, 1.000], mean action: 3.469 [0.000, 6.000], mean observation: 165.881 [18.000, 255.000], loss: 0.087538, mean_absolute_error: 51.124523, mean_q: 59.769696, mean_eps: 0.100000
#  1312788/2000000: episode: 4039, duration: 20.554s, episode steps: 478, steps per second: 23, episode reward: 435.500, mean reward: 0.911 [0.500, 1.000], mean action: 3.636 [0.000, 6.000], mean observation: 165.702 [0.000, 255.000], loss: 0.083178, mean_absolute_error: 51.371316, mean_q: 60.051425, mean_eps: 0.100000
#  1313262/2000000: episode: 4040, duration: 20.504s, episode steps: 474, steps per second: 23, episode reward: 424.500, mean reward: 0.896 [0.500, 1.000], mean action: 3.749 [0.000, 6.000], mean observation: 164.916 [0.000, 255.000], loss: 0.081818, mean_absolute_error: 51.561626, mean_q: 60.283895, mean_eps: 0.100000
# done, took 66109.603 seconds

# %% [markdown]
# ### continue training

# %%
# weights_filename = join(log_dir,'dqn_{}_weights_{}.h5f'.format('AirSimCarRL', 500000))
# dqn.load_weights(weights_filename)
# dqn.test(env, nb_episodes=10, visualize=True)

# %% [markdown]
# ### testing

# %%
log_dir = 'logs'
if not exists(log_dir):
    os.makedirs(log_dir)
    
weights_filename = join(log_dir,'dqn_{}_weights_{}.h5f'.format('AirSimCarRL', 1000000))
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=True)
