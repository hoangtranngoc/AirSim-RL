# %% [markdown]
# ### this notebook is a copy of train.py

# %%
from rl.callbacks import ModelIntervalCheckpoint, FileLogger
from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, Concatenate
from gym import spaces
import numpy as np
from PIL import Image
from configparser import ConfigParser
import os
from os.path import join, pardir, exists
from pathlib import Path

from gym_airsim.airsim_car_env import AirSimCarEnv

import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  #dynamically grow the memory used on the GPU
set_session(tf.Session(config=config))

class AirSimCarProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')  # resize and convert to grayscale
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')  # saves storage in experience memory

    def process_state_batch(self, batch):
        # We could perform this processing step in `process_observation`. In this case, however,
        # we would need to store a `float32` array instead, which is 4x more memory intensive than
        # an `uint8` array. This matters if we store 1M observations.
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

config = ConfigParser()
config.read('config.ini')
num_actions = int(config['car_agent']['actions'])
                    
WINDOW_LENGTH = 4
INPUT_SHAPE = (84, 84)

env = AirSimCarEnv()
np.random.seed(123)

# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
model.add(Permute((2, 3, 1), input_shape=input_shape))
model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(num_actions))
model.add(Activation('linear'))
print(model.summary())

log_dir = 'logs'
if not exists(log_dir):
    os.makedirs(log_dir)
tensorboard_dir = Path("logs/keras-rl_dqn_AirsimCar_tensorboard/")
if not exists(tensorboard_dir):
    os.makedirs(tensorboard_dir)

memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(),  attr='eps', value_max=1., 
                              value_min=.1, value_test=.05, nb_steps=1000000)
processor = AirSimCarProcessor()

dqn = DQNAgent(model=model, nb_actions=num_actions, policy=policy, memory=memory,
               processor=processor, nb_steps_warmup=50000, gamma=.99, target_model_update=10000,
               train_interval=4, delta_clip=1.)
dqn.compile(Adam(lr=.0001), metrics=['mae'])

def build_callbacks(env_name):
    log_dir = 'logs'
    if not exists(log_dir):
        os.makedirs(log_dir)
    
    checkpoint_weights_filename = join(log_dir, 'dqn_' + env_name + '_weights_{step}.h5f')
    log_filename = join(log_dir,'dqn_{}_log.json'.format(env_name))
    callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=25000)]
    callbacks += [FileLogger(log_filename, interval=100)]
    return callbacks

callbacks = build_callbacks('AirSimCarRL')

dqn.fit(env, nb_steps=1000000,
        visualize=False,
        verbose=2,
        callbacks=callbacks)
# Out:
# Using TensorFlow backend.
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)
#
# ['WayPoint0', 'WayPoint1', 'WayPoint2', 'WayPoint3', 'WayPoint4', 'WayPoint5', 'WayPoint6', 'WayPoint7', 'WayPoint8', 'WayPoint9']
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# permute_1 (Permute)          (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# activation_1 (Activation)    (None, 20, 20, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation_5 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 1,687,719
# Trainable params: 1,687,719
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Hoang\Anaconda3\envs\tf_gpu\lib\site-packages\rl\util.py:79: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Training for 1000000 steps ...
#     226/1000000: episode: 1, duration: 10.554s, episode steps: 226, steps per second: 21, episode reward: 91.500, mean reward: 0.405 [-1.000, 0.500], mean action: 2.894 [0.000, 6.000], mean observation: 172.303 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     391/1000000: episode: 2, duration: 7.977s, episode steps: 165, steps per second: 21, episode reward: 82.900, mean reward: 0.502 [-1.000, 1.000], mean action: 3.297 [0.000, 6.000], mean observation: 174.005 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     598/1000000: episode: 3, duration: 9.131s, episode steps: 207, steps per second: 23, episode reward: 103.000, mean reward: 0.498 [-1.000, 1.000], mean action: 3.053 [0.000, 6.000], mean observation: 171.886 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#     807/1000000: episode: 4, duration: 9.272s, episode steps: 209, steps per second: 23, episode reward: 129.800, mean reward: 0.621 [-1.000, 1.000], mean action: 3.043 [0.000, 6.000], mean observation: 171.715 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    1033/1000000: episode: 5, duration: 10.289s, episode steps: 226, steps per second: 22, episode reward: 141.700, mean reward: 0.627 [-1.000, 1.000], mean action: 2.965 [0.000, 6.000], mean observation: 173.522 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    1242/1000000: episode: 6, duration: 9.236s, episode steps: 209, steps per second: 23, episode reward: 127.200, mean reward: 0.609 [-1.000, 1.000], mean action: 3.014 [0.000, 6.000], mean observation: 171.685 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    1409/1000000: episode: 7, duration: 7.097s, episode steps: 167, steps per second: 24, episode reward: 61.200, mean reward: 0.366 [-1.000, 0.500], mean action: 2.940 [0.000, 6.000], mean observation: 172.052 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    1592/1000000: episode: 8, duration: 7.999s, episode steps: 183, steps per second: 23, episode reward: 84.300, mean reward: 0.461 [-1.000, 1.000], mean action: 2.869 [0.000, 6.000], mean observation: 171.358 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    1804/1000000: episode: 9, duration: 9.912s, episode steps: 212, steps per second: 21, episode reward: 150.700, mean reward: 0.711 [-1.000, 1.000], mean action: 2.901 [0.000, 6.000], mean observation: 172.108 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    2004/1000000: episode: 10, duration: 8.848s, episode steps: 200, steps per second: 23, episode reward: 69.300, mean reward: 0.347 [-1.000, 0.500], mean action: 3.085 [0.000, 6.000], mean observation: 172.257 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    2200/1000000: episode: 11, duration: 8.669s, episode steps: 196, steps per second: 23, episode reward: 86.900, mean reward: 0.443 [-1.000, 1.000], mean action: 2.903 [0.000, 6.000], mean observation: 171.970 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    2400/1000000: episode: 12, duration: 8.749s, episode steps: 200, steps per second: 23, episode reward: 69.700, mean reward: 0.349 [-1.000, 0.500], mean action: 3.020 [0.000, 6.000], mean observation: 172.315 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    2605/1000000: episode: 13, duration: 9.536s, episode steps: 205, steps per second: 21, episode reward: 121.300, mean reward: 0.592 [-1.000, 1.000], mean action: 2.902 [0.000, 6.000], mean observation: 171.683 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    2826/1000000: episode: 14, duration: 10.454s, episode steps: 221, steps per second: 21, episode reward: 132.500, mean reward: 0.600 [-1.000, 1.000], mean action: 3.090 [0.000, 6.000], mean observation: 172.270 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    3025/1000000: episode: 15, duration: 8.757s, episode steps: 199, steps per second: 23, episode reward: 94.100, mean reward: 0.473 [-1.000, 1.000], mean action: 2.950 [0.000, 6.000], mean observation: 171.624 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    3233/1000000: episode: 16, duration: 9.577s, episode steps: 208, steps per second: 22, episode reward: 133.000, mean reward: 0.639 [-1.000, 1.000], mean action: 3.096 [0.000, 6.000], mean observation: 171.514 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    3412/1000000: episode: 17, duration: 7.610s, episode steps: 179, steps per second: 24, episode reward: 64.400, mean reward: 0.360 [-1.000, 0.500], mean action: 2.883 [0.000, 6.000], mean observation: 172.089 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    3617/1000000: episode: 18, duration: 9.439s, episode steps: 205, steps per second: 22, episode reward: 130.800, mean reward: 0.638 [-1.000, 1.000], mean action: 3.034 [0.000, 6.000], mean observation: 171.188 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    3812/1000000: episode: 19, duration: 8.486s, episode steps: 195, steps per second: 23, episode reward: 78.800, mean reward: 0.404 [-1.000, 0.500], mean action: 2.969 [0.000, 6.000], mean observation: 172.394 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    3970/1000000: episode: 20, duration: 6.668s, episode steps: 158, steps per second: 24, episode reward: 57.500, mean reward: 0.364 [-1.000, 0.500], mean action: 2.747 [0.000, 6.000], mean observation: 172.122 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    4153/1000000: episode: 21, duration: 7.960s, episode steps: 183, steps per second: 23, episode reward: 74.800, mean reward: 0.409 [-1.000, 0.500], mean action: 2.896 [0.000, 6.000], mean observation: 171.439 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    4357/1000000: episode: 22, duration: 9.336s, episode steps: 204, steps per second: 22, episode reward: 126.300, mean reward: 0.619 [-1.000, 1.000], mean action: 2.985 [0.000, 6.000], mean observation: 171.098 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    4558/1000000: episode: 23, duration: 9.111s, episode steps: 201, steps per second: 22, episode reward: 100.200, mean reward: 0.499 [-1.000, 1.000], mean action: 2.970 [0.000, 6.000], mean observation: 171.227 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    4756/1000000: episode: 24, duration: 8.800s, episode steps: 198, steps per second: 22, episode reward: 89.600, mean reward: 0.453 [-1.000, 1.000], mean action: 3.005 [0.000, 6.000], mean observation: 171.306 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    5002/1000000: episode: 25, duration: 11.860s, episode steps: 246, steps per second: 21, episode reward: 138.800, mean reward: 0.564 [-1.000, 1.000], mean action: 3.228 [0.000, 6.000], mean observation: 172.509 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    5203/1000000: episode: 26, duration: 9.071s, episode steps: 201, steps per second: 22, episode reward: 137.700, mean reward: 0.685 [-1.000, 1.000], mean action: 3.020 [0.000, 6.000], mean observation: 170.711 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    5402/1000000: episode: 27, duration: 8.677s, episode steps: 199, steps per second: 23, episode reward: 77.200, mean reward: 0.388 [-1.000, 0.500], mean action: 2.915 [0.000, 6.000], mean observation: 171.747 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    5599/1000000: episode: 28, duration: 8.546s, episode steps: 197, steps per second: 23, episode reward: 75.000, mean reward: 0.381 [-1.000, 0.500], mean action: 3.056 [0.000, 6.000], mean observation: 171.972 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    5768/1000000: episode: 29, duration: 7.272s, episode steps: 169, steps per second: 23, episode reward: 70.200, mean reward: 0.415 [-1.000, 0.500], mean action: 2.805 [0.000, 6.000], mean observation: 171.344 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    6022/1000000: episode: 30, duration: 12.308s, episode steps: 254, steps per second: 21, episode reward: 160.800, mean reward: 0.633 [-1.000, 1.000], mean action: 3.295 [0.000, 6.000], mean observation: 172.424 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    6179/1000000: episode: 31, duration: 6.731s, episode steps: 157, steps per second: 23, episode reward: 61.400, mean reward: 0.391 [-1.000, 0.500], mean action: 2.592 [0.000, 6.000], mean observation: 171.439 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    6335/1000000: episode: 32, duration: 6.496s, episode steps: 156, steps per second: 24, episode reward: 54.500, mean reward: 0.349 [-1.000, 0.500], mean action: 2.718 [0.000, 6.000], mean observation: 171.997 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    6549/1000000: episode: 33, duration: 10.029s, episode steps: 214, steps per second: 21, episode reward: 149.300, mean reward: 0.698 [-1.000, 1.000], mean action: 3.005 [0.000, 6.000], mean observation: 171.596 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    6720/1000000: episode: 34, duration: 7.403s, episode steps: 171, steps per second: 23, episode reward: 72.000, mean reward: 0.421 [-1.000, 0.500], mean action: 2.830 [0.000, 6.000], mean observation: 171.134 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    6948/1000000: episode: 35, duration: 10.895s, episode steps: 228, steps per second: 21, episode reward: 164.100, mean reward: 0.720 [-1.000, 1.000], mean action: 3.101 [0.000, 6.000], mean observation: 172.045 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    7150/1000000: episode: 36, duration: 9.313s, episode steps: 202, steps per second: 22, episode reward: 100.300, mean reward: 0.497 [-1.000, 1.000], mean action: 2.955 [0.000, 6.000], mean observation: 171.374 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    7306/1000000: episode: 37, duration: 6.495s, episode steps: 156, steps per second: 24, episode reward: 55.300, mean reward: 0.354 [-1.000, 0.500], mean action: 2.853 [0.000, 6.000], mean observation: 172.224 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    7531/1000000: episode: 38, duration: 10.737s, episode steps: 225, steps per second: 21, episode reward: 153.100, mean reward: 0.680 [-1.000, 1.000], mean action: 3.253 [0.000, 6.000], mean observation: 172.034 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    7733/1000000: episode: 39, duration: 9.192s, episode steps: 202, steps per second: 22, episode reward: 87.500, mean reward: 0.433 [-1.000, 0.500], mean action: 2.832 [0.000, 6.000], mean observation: 171.482 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    7924/1000000: episode: 40, duration: 8.318s, episode steps: 191, steps per second: 23, episode reward: 77.600, mean reward: 0.406 [-1.000, 0.500], mean action: 2.990 [0.000, 6.000], mean observation: 171.258 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    8119/1000000: episode: 41, duration: 8.490s, episode steps: 195, steps per second: 23, episode reward: 78.800, mean reward: 0.404 [-1.000, 0.500], mean action: 3.036 [0.000, 6.000], mean observation: 171.581 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    8315/1000000: episode: 42, duration: 8.694s, episode steps: 196, steps per second: 23, episode reward: 110.800, mean reward: 0.565 [-1.000, 1.000], mean action: 2.862 [0.000, 6.000], mean observation: 171.308 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    8484/1000000: episode: 43, duration: 7.210s, episode steps: 169, steps per second: 23, episode reward: 70.200, mean reward: 0.415 [-1.000, 0.500], mean action: 2.828 [0.000, 6.000], mean observation: 171.942 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    8651/1000000: episode: 44, duration: 7.186s, episode steps: 167, steps per second: 23, episode reward: 70.800, mean reward: 0.424 [-1.000, 0.500], mean action: 2.892 [0.000, 6.000], mean observation: 171.526 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    8826/1000000: episode: 45, duration: 7.522s, episode steps: 175, steps per second: 23, episode reward: 70.000, mean reward: 0.400 [-1.000, 0.500], mean action: 2.789 [0.000, 6.000], mean observation: 171.645 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    8997/1000000: episode: 46, duration: 7.159s, episode steps: 171, steps per second: 24, episode reward: 56.000, mean reward: 0.327 [-1.000, 0.500], mean action: 2.953 [0.000, 6.000], mean observation: 172.070 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    9198/1000000: episode: 47, duration: 8.885s, episode steps: 201, steps per second: 23, episode reward: 77.800, mean reward: 0.387 [-1.000, 0.500], mean action: 2.945 [0.000, 6.000], mean observation: 171.758 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    9423/1000000: episode: 48, duration: 10.598s, episode steps: 225, steps per second: 21, episode reward: 131.300, mean reward: 0.584 [-1.000, 1.000], mean action: 2.987 [0.000, 6.000], mean observation: 172.342 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    9625/1000000: episode: 49, duration: 9.295s, episode steps: 202, steps per second: 22, episode reward: 113.300, mean reward: 0.561 [-1.000, 1.000], mean action: 2.965 [0.000, 6.000], mean observation: 171.640 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#    9868/1000000: episode: 50, duration: 11.714s, episode steps: 243, steps per second: 21, episode reward: 121.800, mean reward: 0.501 [-1.000, 1.000], mean action: 3.333 [0.000, 6.000], mean observation: 172.466 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   10053/1000000: episode: 51, duration: 8.118s, episode steps: 185, steps per second: 23, episode reward: 76.600, mean reward: 0.414 [-1.000, 0.500], mean action: 2.849 [0.000, 6.000], mean observation: 171.755 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   10260/1000000: episode: 52, duration: 9.654s, episode steps: 207, steps per second: 21, episode reward: 118.300, mean reward: 0.571 [-1.000, 1.000], mean action: 3.130 [0.000, 6.000], mean observation: 172.248 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   10473/1000000: episode: 53, duration: 10.104s, episode steps: 213, steps per second: 21, episode reward: 143.000, mean reward: 0.671 [-1.000, 1.000], mean action: 3.066 [0.000, 6.000], mean observation: 172.190 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   10669/1000000: episode: 54, duration: 8.703s, episode steps: 196, steps per second: 23, episode reward: 104.300, mean reward: 0.532 [-1.000, 1.000], mean action: 2.709 [0.000, 6.000], mean observation: 171.835 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   10871/1000000: episode: 55, duration: 9.374s, episode steps: 202, steps per second: 22, episode reward: 105.300, mean reward: 0.521 [-1.000, 1.000], mean action: 3.104 [0.000, 6.000], mean observation: 172.007 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   11072/1000000: episode: 56, duration: 9.221s, episode steps: 201, steps per second: 22, episode reward: 91.700, mean reward: 0.456 [-1.000, 1.000], mean action: 2.945 [0.000, 6.000], mean observation: 172.438 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   11277/1000000: episode: 57, duration: 9.219s, episode steps: 205, steps per second: 22, episode reward: 67.800, mean reward: 0.331 [-1.000, 0.500], mean action: 3.127 [0.000, 6.000], mean observation: 172.676 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   11437/1000000: episode: 58, duration: 6.675s, episode steps: 160, steps per second: 24, episode reward: 54.100, mean reward: 0.338 [-1.000, 0.500], mean action: 2.769 [0.000, 6.000], mean observation: 172.970 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   11620/1000000: episode: 59, duration: 7.989s, episode steps: 183, steps per second: 23, episode reward: 75.600, mean reward: 0.413 [-1.000, 0.500], mean action: 2.902 [0.000, 6.000], mean observation: 172.190 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   11816/1000000: episode: 60, duration: 8.721s, episode steps: 196, steps per second: 22, episode reward: 83.600, mean reward: 0.427 [-1.000, 1.000], mean action: 2.898 [0.000, 6.000], mean observation: 172.485 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   11995/1000000: episode: 61, duration: 7.790s, episode steps: 179, steps per second: 23, episode reward: 72.800, mean reward: 0.407 [-1.000, 0.500], mean action: 2.827 [0.000, 6.000], mean observation: 172.339 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   12219/1000000: episode: 62, duration: 10.617s, episode steps: 224, steps per second: 21, episode reward: 137.500, mean reward: 0.614 [-1.000, 1.000], mean action: 3.156 [0.000, 6.000], mean observation: 173.191 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   12377/1000000: episode: 63, duration: 6.656s, episode steps: 158, steps per second: 24, episode reward: 55.100, mean reward: 0.349 [-1.000, 0.500], mean action: 2.753 [0.000, 6.000], mean observation: 172.795 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   12594/1000000: episode: 64, duration: 10.182s, episode steps: 217, steps per second: 21, episode reward: 135.300, mean reward: 0.624 [-1.000, 1.000], mean action: 3.138 [0.000, 6.000], mean observation: 173.095 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   12816/1000000: episode: 65, duration: 10.616s, episode steps: 222, steps per second: 21, episode reward: 132.400, mean reward: 0.596 [-1.000, 1.000], mean action: 3.122 [0.000, 6.000], mean observation: 172.949 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   13017/1000000: episode: 66, duration: 9.166s, episode steps: 201, steps per second: 22, episode reward: 110.800, mean reward: 0.551 [-1.000, 1.000], mean action: 3.025 [0.000, 6.000], mean observation: 172.174 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   13198/1000000: episode: 67, duration: 7.651s, episode steps: 181, steps per second: 24, episode reward: 58.200, mean reward: 0.322 [-1.000, 0.500], mean action: 3.000 [0.000, 6.000], mean observation: 172.818 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   13350/1000000: episode: 68, duration: 7.545s, episode steps: 152, steps per second: 20, episode reward: 82.800, mean reward: 0.545 [-1.000, 1.000], mean action: 3.546 [0.000, 6.000], mean observation: 173.133 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   13550/1000000: episode: 69, duration: 8.952s, episode steps: 200, steps per second: 22, episode reward: 128.600, mean reward: 0.643 [-1.000, 1.000], mean action: 3.015 [0.000, 6.000], mean observation: 171.793 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   13779/1000000: episode: 70, duration: 10.961s, episode steps: 229, steps per second: 21, episode reward: 153.100, mean reward: 0.669 [-1.000, 1.000], mean action: 3.087 [0.000, 6.000], mean observation: 173.299 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   14006/1000000: episode: 71, duration: 10.866s, episode steps: 227, steps per second: 21, episode reward: 161.200, mean reward: 0.710 [-1.000, 1.000], mean action: 3.185 [0.000, 6.000], mean observation: 173.138 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   14214/1000000: episode: 72, duration: 9.800s, episode steps: 208, steps per second: 21, episode reward: 117.400, mean reward: 0.564 [-1.000, 1.000], mean action: 3.014 [0.000, 6.000], mean observation: 172.506 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   14384/1000000: episode: 73, duration: 7.231s, episode steps: 170, steps per second: 24, episode reward: 67.500, mean reward: 0.397 [-1.000, 0.500], mean action: 2.753 [0.000, 6.000], mean observation: 172.800 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   14620/1000000: episode: 74, duration: 11.330s, episode steps: 236, steps per second: 21, episode reward: 149.900, mean reward: 0.635 [-1.000, 1.000], mean action: 3.089 [0.000, 6.000], mean observation: 173.118 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   14823/1000000: episode: 75, duration: 9.301s, episode steps: 203, steps per second: 22, episode reward: 97.300, mean reward: 0.479 [-1.000, 1.000], mean action: 3.123 [0.000, 6.000], mean observation: 172.623 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   15037/1000000: episode: 76, duration: 9.967s, episode steps: 214, steps per second: 21, episode reward: 162.300, mean reward: 0.758 [-1.000, 1.000], mean action: 3.121 [0.000, 6.000], mean observation: 172.435 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   15215/1000000: episode: 77, duration: 7.508s, episode steps: 178, steps per second: 24, episode reward: 57.100, mean reward: 0.321 [-1.000, 0.500], mean action: 3.051 [0.000, 6.000], mean observation: 173.005 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   15412/1000000: episode: 78, duration: 8.666s, episode steps: 197, steps per second: 23, episode reward: 79.800, mean reward: 0.405 [-1.000, 0.500], mean action: 2.741 [0.000, 6.000], mean observation: 172.705 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   15615/1000000: episode: 79, duration: 9.307s, episode steps: 203, steps per second: 22, episode reward: 102.700, mean reward: 0.506 [-1.000, 1.000], mean action: 3.020 [0.000, 6.000], mean observation: 172.492 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   15840/1000000: episode: 80, duration: 10.674s, episode steps: 225, steps per second: 21, episode reward: 137.300, mean reward: 0.610 [-1.000, 1.000], mean action: 3.093 [0.000, 6.000], mean observation: 173.212 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   16009/1000000: episode: 81, duration: 7.346s, episode steps: 169, steps per second: 23, episode reward: 70.600, mean reward: 0.418 [-1.000, 0.500], mean action: 2.923 [0.000, 6.000], mean observation: 172.203 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   16216/1000000: episode: 82, duration: 9.535s, episode steps: 207, steps per second: 22, episode reward: 135.700, mean reward: 0.656 [-1.000, 1.000], mean action: 2.918 [0.000, 6.000], mean observation: 172.067 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   16468/1000000: episode: 83, duration: 12.230s, episode steps: 252, steps per second: 21, episode reward: 162.900, mean reward: 0.646 [-1.000, 1.000], mean action: 3.234 [0.000, 6.000], mean observation: 172.984 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   16665/1000000: episode: 84, duration: 8.582s, episode steps: 197, steps per second: 23, episode reward: 77.000, mean reward: 0.391 [-1.000, 0.500], mean action: 3.096 [0.000, 6.000], mean observation: 172.820 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   16884/1000000: episode: 85, duration: 10.367s, episode steps: 219, steps per second: 21, episode reward: 164.300, mean reward: 0.750 [-1.000, 1.000], mean action: 3.073 [0.000, 6.000], mean observation: 172.918 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   17051/1000000: episode: 86, duration: 7.214s, episode steps: 167, steps per second: 23, episode reward: 72.400, mean reward: 0.434 [-1.000, 1.000], mean action: 2.982 [0.000, 6.000], mean observation: 171.895 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   17250/1000000: episode: 87, duration: 8.839s, episode steps: 199, steps per second: 23, episode reward: 127.200, mean reward: 0.639 [-1.000, 1.000], mean action: 2.995 [0.000, 6.000], mean observation: 171.263 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   17435/1000000: episode: 88, duration: 8.108s, episode steps: 185, steps per second: 23, episode reward: 111.100, mean reward: 0.601 [-1.000, 1.000], mean action: 2.811 [0.000, 6.000], mean observation: 171.234 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   17615/1000000: episode: 89, duration: 7.729s, episode steps: 180, steps per second: 23, episode reward: 69.700, mean reward: 0.387 [-1.000, 0.500], mean action: 3.022 [0.000, 6.000], mean observation: 172.170 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   17817/1000000: episode: 90, duration: 9.291s, episode steps: 202, steps per second: 22, episode reward: 95.500, mean reward: 0.473 [-1.000, 1.000], mean action: 3.074 [0.000, 6.000], mean observation: 171.951 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   18026/1000000: episode: 91, duration: 9.616s, episode steps: 209, steps per second: 22, episode reward: 100.600, mean reward: 0.481 [-1.000, 1.000], mean action: 3.182 [0.000, 6.000], mean observation: 171.941 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   18275/1000000: episode: 92, duration: 12.066s, episode steps: 249, steps per second: 21, episode reward: 119.300, mean reward: 0.479 [-1.000, 1.000], mean action: 3.173 [0.000, 6.000], mean observation: 173.570 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   18523/1000000: episode: 93, duration: 11.977s, episode steps: 248, steps per second: 21, episode reward: 148.700, mean reward: 0.600 [-1.000, 1.000], mean action: 3.190 [0.000, 6.000], mean observation: 172.759 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   18731/1000000: episode: 94, duration: 9.708s, episode steps: 208, steps per second: 21, episode reward: 130.800, mean reward: 0.629 [-1.000, 1.000], mean action: 2.986 [0.000, 6.000], mean observation: 171.948 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   18936/1000000: episode: 95, duration: 9.441s, episode steps: 205, steps per second: 22, episode reward: 100.900, mean reward: 0.492 [-1.000, 1.000], mean action: 3.068 [0.000, 6.000], mean observation: 171.910 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   19150/1000000: episode: 96, duration: 10.123s, episode steps: 214, steps per second: 21, episode reward: 139.900, mean reward: 0.654 [-1.000, 1.000], mean action: 3.033 [0.000, 6.000], mean observation: 172.292 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   19367/1000000: episode: 97, duration: 10.173s, episode steps: 217, steps per second: 21, episode reward: 102.000, mean reward: 0.470 [-1.000, 1.000], mean action: 3.083 [0.000, 6.000], mean observation: 172.139 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   19571/1000000: episode: 98, duration: 9.377s, episode steps: 204, steps per second: 22, episode reward: 131.700, mean reward: 0.646 [-1.000, 1.000], mean action: 2.887 [0.000, 6.000], mean observation: 171.353 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   19773/1000000: episode: 99, duration: 9.174s, episode steps: 202, steps per second: 22, episode reward: 84.700, mean reward: 0.419 [-1.000, 0.500], mean action: 2.916 [0.000, 6.000], mean observation: 171.977 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   19970/1000000: episode: 100, duration: 8.605s, episode steps: 197, steps per second: 23, episode reward: 81.900, mean reward: 0.416 [-1.000, 1.000], mean action: 3.056 [0.000, 6.000], mean observation: 171.567 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   20169/1000000: episode: 101, duration: 8.838s, episode steps: 199, steps per second: 23, episode reward: 124.700, mean reward: 0.627 [-1.000, 1.000], mean action: 3.010 [0.000, 6.000], mean observation: 170.906 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   20398/1000000: episode: 102, duration: 10.789s, episode steps: 229, steps per second: 21, episode reward: 107.300, mean reward: 0.469 [-1.000, 1.000], mean action: 3.183 [0.000, 6.000], mean observation: 172.281 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   20597/1000000: episode: 103, duration: 8.891s, episode steps: 199, steps per second: 22, episode reward: 90.200, mean reward: 0.453 [-1.000, 1.000], mean action: 2.814 [0.000, 6.000], mean observation: 171.602 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   20795/1000000: episode: 104, duration: 8.893s, episode steps: 198, steps per second: 22, episode reward: 90.100, mean reward: 0.455 [-1.000, 1.000], mean action: 3.071 [0.000, 6.000], mean observation: 171.814 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   20945/1000000: episode: 105, duration: 6.223s, episode steps: 150, steps per second: 24, episode reward: 52.700, mean reward: 0.351 [-1.000, 0.500], mean action: 2.780 [0.000, 6.000], mean observation: 172.923 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   21153/1000000: episode: 106, duration: 9.503s, episode steps: 208, steps per second: 22, episode reward: 94.900, mean reward: 0.456 [-1.000, 0.500], mean action: 3.130 [0.000, 6.000], mean observation: 172.451 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   21353/1000000: episode: 107, duration: 8.900s, episode steps: 200, steps per second: 22, episode reward: 123.000, mean reward: 0.615 [-1.000, 1.000], mean action: 2.945 [0.000, 6.000], mean observation: 171.315 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   21577/1000000: episode: 108, duration: 10.630s, episode steps: 224, steps per second: 21, episode reward: 149.500, mean reward: 0.667 [-1.000, 1.000], mean action: 3.134 [0.000, 6.000], mean observation: 172.512 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   21808/1000000: episode: 109, duration: 11.070s, episode steps: 231, steps per second: 21, episode reward: 139.800, mean reward: 0.605 [-1.000, 1.000], mean action: 3.156 [0.000, 6.000], mean observation: 172.793 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   22010/1000000: episode: 110, duration: 9.110s, episode steps: 202, steps per second: 22, episode reward: 79.500, mean reward: 0.394 [-1.000, 0.500], mean action: 3.183 [0.000, 6.000], mean observation: 172.306 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   22186/1000000: episode: 111, duration: 7.456s, episode steps: 176, steps per second: 24, episode reward: 57.700, mean reward: 0.328 [-1.000, 0.500], mean action: 2.949 [0.000, 6.000], mean observation: 172.475 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   22392/1000000: episode: 112, duration: 9.450s, episode steps: 206, steps per second: 22, episode reward: 103.800, mean reward: 0.504 [-1.000, 1.000], mean action: 2.917 [0.000, 6.000], mean observation: 172.243 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   22594/1000000: episode: 113, duration: 9.246s, episode steps: 202, steps per second: 22, episode reward: 93.200, mean reward: 0.461 [-1.000, 1.000], mean action: 3.050 [0.000, 6.000], mean observation: 172.293 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   22800/1000000: episode: 114, duration: 9.388s, episode steps: 206, steps per second: 22, episode reward: 144.400, mean reward: 0.701 [-1.000, 1.000], mean action: 3.150 [0.000, 6.000], mean observation: 171.470 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   23001/1000000: episode: 115, duration: 9.119s, episode steps: 201, steps per second: 22, episode reward: 104.200, mean reward: 0.518 [-1.000, 1.000], mean action: 2.920 [0.000, 6.000], mean observation: 172.358 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   23225/1000000: episode: 116, duration: 10.648s, episode steps: 224, steps per second: 21, episode reward: 157.300, mean reward: 0.702 [-1.000, 1.000], mean action: 3.205 [0.000, 6.000], mean observation: 173.141 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   23397/1000000: episode: 117, duration: 7.400s, episode steps: 172, steps per second: 23, episode reward: 68.100, mean reward: 0.396 [-1.000, 0.500], mean action: 2.971 [0.000, 6.000], mean observation: 172.648 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   23577/1000000: episode: 118, duration: 7.628s, episode steps: 180, steps per second: 24, episode reward: 59.300, mean reward: 0.329 [-1.000, 0.500], mean action: 2.844 [0.000, 6.000], mean observation: 173.008 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   23779/1000000: episode: 119, duration: 9.453s, episode steps: 202, steps per second: 21, episode reward: 100.800, mean reward: 0.499 [-1.000, 1.000], mean action: 3.025 [0.000, 6.000], mean observation: 172.604 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   23977/1000000: episode: 120, duration: 8.662s, episode steps: 198, steps per second: 23, episode reward: 81.400, mean reward: 0.411 [-1.000, 1.000], mean action: 2.934 [0.000, 6.000], mean observation: 172.770 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   24192/1000000: episode: 121, duration: 10.044s, episode steps: 215, steps per second: 21, episode reward: 137.400, mean reward: 0.639 [-1.000, 1.000], mean action: 3.074 [0.000, 6.000], mean observation: 173.133 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   24374/1000000: episode: 122, duration: 7.875s, episode steps: 182, steps per second: 23, episode reward: 74.700, mean reward: 0.410 [-1.000, 0.500], mean action: 2.846 [0.000, 6.000], mean observation: 172.339 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   24566/1000000: episode: 123, duration: 8.346s, episode steps: 192, steps per second: 23, episode reward: 76.100, mean reward: 0.396 [-1.000, 0.500], mean action: 2.932 [0.000, 6.000], mean observation: 172.753 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   24750/1000000: episode: 124, duration: 7.879s, episode steps: 184, steps per second: 23, episode reward: 70.500, mean reward: 0.383 [-1.000, 0.500], mean action: 2.821 [0.000, 6.000], mean observation: 172.994 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   24962/1000000: episode: 125, duration: 9.948s, episode steps: 212, steps per second: 21, episode reward: 137.300, mean reward: 0.648 [-1.000, 1.000], mean action: 3.028 [0.000, 6.000], mean observation: 172.775 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   25075/1000000: episode: 126, duration: 4.872s, episode steps: 113, steps per second: 23, episode reward: 38.600, mean reward: 0.342 [-1.000, 0.500], mean action: 2.442 [0.000, 6.000], mean observation: 172.671 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   25274/1000000: episode: 127, duration: 8.760s, episode steps: 199, steps per second: 23, episode reward: 78.000, mean reward: 0.392 [-1.000, 0.500], mean action: 2.930 [0.000, 6.000], mean observation: 172.998 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   25518/1000000: episode: 128, duration: 11.656s, episode steps: 244, steps per second: 21, episode reward: 157.600, mean reward: 0.646 [-1.000, 1.000], mean action: 3.131 [0.000, 6.000], mean observation: 173.690 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   25755/1000000: episode: 129, duration: 11.353s, episode steps: 237, steps per second: 21, episode reward: 170.600, mean reward: 0.720 [-1.000, 1.000], mean action: 3.127 [0.000, 6.000], mean observation: 173.204 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   25976/1000000: episode: 130, duration: 10.508s, episode steps: 221, steps per second: 21, episode reward: 152.100, mean reward: 0.688 [-1.000, 1.000], mean action: 3.154 [0.000, 6.000], mean observation: 173.032 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   26173/1000000: episode: 131, duration: 8.650s, episode steps: 197, steps per second: 23, episode reward: 109.100, mean reward: 0.554 [-1.000, 1.000], mean action: 2.888 [0.000, 6.000], mean observation: 172.353 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   26388/1000000: episode: 132, duration: 10.022s, episode steps: 215, steps per second: 21, episode reward: 95.900, mean reward: 0.446 [-1.000, 1.000], mean action: 3.116 [0.000, 6.000], mean observation: 173.223 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   26590/1000000: episode: 133, duration: 8.985s, episode steps: 202, steps per second: 22, episode reward: 131.200, mean reward: 0.650 [-1.000, 1.000], mean action: 2.832 [0.000, 6.000], mean observation: 171.385 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   26796/1000000: episode: 134, duration: 9.634s, episode steps: 206, steps per second: 21, episode reward: 121.400, mean reward: 0.589 [-1.000, 1.000], mean action: 2.985 [0.000, 6.000], mean observation: 172.355 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   26994/1000000: episode: 135, duration: 8.673s, episode steps: 198, steps per second: 23, episode reward: 79.100, mean reward: 0.399 [-1.000, 0.500], mean action: 2.859 [0.000, 6.000], mean observation: 172.918 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   27188/1000000: episode: 136, duration: 8.494s, episode steps: 194, steps per second: 23, episode reward: 80.400, mean reward: 0.414 [-1.000, 1.000], mean action: 3.088 [0.000, 6.000], mean observation: 172.311 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   27388/1000000: episode: 137, duration: 8.601s, episode steps: 200, steps per second: 23, episode reward: 60.900, mean reward: 0.305 [-1.000, 0.500], mean action: 2.770 [0.000, 6.000], mean observation: 173.244 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   27552/1000000: episode: 138, duration: 6.928s, episode steps: 164, steps per second: 24, episode reward: 60.100, mean reward: 0.366 [-1.000, 0.500], mean action: 2.732 [0.000, 6.000], mean observation: 172.611 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
#   27787/1000000: episode: 139, duration: 11.025s, episode steps: 235, steps per second: 21, episode reward: 120.700, mean reward: 0.514 [-1.000, 1.000], mean action: 3.132 [0.000, 6.000], mean observation: 173.470 [0.000, 255.000], loss: --, mean_absolute_error: --, mean_q: --, mean_eps: --
# ...
#  778545/1000000: episode: 3288, duration: 20.628s, episode steps: 476, steps per second: 23, episode reward: 366.000, mean reward: 0.769 [0.500, 1.000], mean action: 3.590 [0.000, 6.000], mean observation: 166.049 [0.000, 255.000], loss: 0.401079, mean_absolute_error: 28.928208, mean_q: 33.872866, mean_eps: 0.299523
#  779018/1000000: episode: 3289, duration: 20.446s, episode steps: 473, steps per second: 23, episode reward: 379.000, mean reward: 0.801 [0.500, 1.000], mean action: 3.569 [0.000, 6.000], mean observation: 166.127 [0.000, 255.000], loss: 0.428246, mean_absolute_error: 28.639322, mean_q: 33.513465, mean_eps: 0.299096
#  779490/1000000: episode: 3290, duration: 20.530s, episode steps: 472, steps per second: 23, episode reward: 377.400, mean reward: 0.800 [0.100, 1.000], mean action: 3.617 [0.000, 6.000], mean observation: 166.071 [0.000, 255.000], loss: 0.395385, mean_absolute_error: 28.841972, mean_q: 33.768045, mean_eps: 0.298671
#  779958/1000000: episode: 3291, duration: 20.404s, episode steps: 468, steps per second: 23, episode reward: 376.000, mean reward: 0.803 [0.500, 1.000], mean action: 3.404 [0.000, 6.000], mean observation: 165.944 [0.000, 255.000], loss: 0.426707, mean_absolute_error: 29.100784, mean_q: 34.061735, mean_eps: 0.298248
#  780432/1000000: episode: 3292, duration: 20.514s, episode steps: 474, steps per second: 23, episode reward: 378.500, mean reward: 0.799 [0.500, 1.000], mean action: 3.399 [0.000, 6.000], mean observation: 165.508 [0.000, 255.000], loss: 0.396091, mean_absolute_error: 29.213315, mean_q: 34.230978, mean_eps: 0.297825
#  780902/1000000: episode: 3293, duration: 20.493s, episode steps: 470, steps per second: 23, episode reward: 421.000, mean reward: 0.896 [0.500, 1.000], mean action: 3.411 [0.000, 6.000], mean observation: 165.556 [0.000, 255.000], loss: 0.394577, mean_absolute_error: 29.170374, mean_q: 34.152006, mean_eps: 0.297401
#  781366/1000000: episode: 3294, duration: 20.424s, episode steps: 464, steps per second: 23, episode reward: 409.000, mean reward: 0.881 [0.500, 1.000], mean action: 3.502 [0.000, 6.000], mean observation: 165.853 [0.000, 255.000], loss: 0.403951, mean_absolute_error: 29.712215, mean_q: 34.805037, mean_eps: 0.296979
#  781839/1000000: episode: 3295, duration: 20.503s, episode steps: 473, steps per second: 23, episode reward: 404.500, mean reward: 0.855 [0.500, 1.000], mean action: 3.556 [0.000, 6.000], mean observation: 165.489 [0.000, 255.000], loss: 0.385772, mean_absolute_error: 29.133719, mean_q: 34.092921, mean_eps: 0.296558
#  782175/1000000: episode: 3296, duration: 15.986s, episode steps: 336, steps per second: 21, episode reward: 263.800, mean reward: 0.785 [-1.000, 1.000], mean action: 3.554 [0.000, 6.000], mean observation: 172.088 [0.000, 255.000], loss: 0.377536, mean_absolute_error: 29.442302, mean_q: 34.449354, mean_eps: 0.296195
#  782606/1000000: episode: 3297, duration: 20.509s, episode steps: 431, steps per second: 21, episode reward: 366.000, mean reward: 0.849 [0.500, 1.000], mean action: 3.601 [0.000, 6.000], mean observation: 164.899 [0.000, 255.000], loss: 0.385386, mean_absolute_error: 29.152257, mean_q: 34.120194, mean_eps: 0.295849
#  783077/1000000: episode: 3298, duration: 20.585s, episode steps: 471, steps per second: 23, episode reward: 401.500, mean reward: 0.852 [0.500, 1.000], mean action: 3.650 [0.000, 6.000], mean observation: 165.180 [0.000, 255.000], loss: 0.376151, mean_absolute_error: 29.003422, mean_q: 33.942446, mean_eps: 0.295442
#  783548/1000000: episode: 3299, duration: 20.567s, episode steps: 471, steps per second: 23, episode reward: 383.500, mean reward: 0.814 [0.500, 1.000], mean action: 3.575 [0.000, 6.000], mean observation: 165.079 [0.000, 255.000], loss: 0.398085, mean_absolute_error: 29.195960, mean_q: 34.175660, mean_eps: 0.295019
#  784022/1000000: episode: 3300, duration: 20.466s, episode steps: 474, steps per second: 23, episode reward: 406.000, mean reward: 0.857 [0.500, 1.000], mean action: 3.447 [0.000, 6.000], mean observation: 165.812 [0.000, 255.000], loss: 0.397905, mean_absolute_error: 29.726162, mean_q: 34.803317, mean_eps: 0.294594
#  784497/1000000: episode: 3301, duration: 20.778s, episode steps: 475, steps per second: 23, episode reward: 378.800, mean reward: 0.797 [0.100, 1.000], mean action: 3.495 [0.000, 6.000], mean observation: 164.307 [0.000, 255.000], loss: 0.381124, mean_absolute_error: 29.776347, mean_q: 34.867618, mean_eps: 0.294166
#  784979/1000000: episode: 3302, duration: 20.691s, episode steps: 482, steps per second: 23, episode reward: 292.400, mean reward: 0.607 [0.100, 1.000], mean action: 3.587 [0.000, 6.000], mean observation: 164.571 [0.000, 255.000], loss: 0.381037, mean_absolute_error: 29.562357, mean_q: 34.597334, mean_eps: 0.293736
#  785454/1000000: episode: 3303, duration: 20.605s, episode steps: 475, steps per second: 23, episode reward: 376.500, mean reward: 0.793 [0.500, 1.000], mean action: 3.558 [0.000, 6.000], mean observation: 165.016 [0.000, 255.000], loss: 0.395001, mean_absolute_error: 28.889637, mean_q: 33.800244, mean_eps: 0.293306
#  785924/1000000: episode: 3304, duration: 20.530s, episode steps: 470, steps per second: 23, episode reward: 394.600, mean reward: 0.840 [0.100, 1.000], mean action: 3.557 [0.000, 6.000], mean observation: 165.631 [0.000, 255.000], loss: 0.398254, mean_absolute_error: 29.582982, mean_q: 34.623431, mean_eps: 0.292881
#  786388/1000000: episode: 3305, duration: 20.646s, episode steps: 464, steps per second: 22, episode reward: 385.500, mean reward: 0.831 [0.500, 1.000], mean action: 3.571 [0.000, 6.000], mean observation: 165.509 [0.000, 255.000], loss: 0.364312, mean_absolute_error: 29.628035, mean_q: 34.678771, mean_eps: 0.292461
#  786858/1000000: episode: 3306, duration: 20.509s, episode steps: 470, steps per second: 23, episode reward: 400.500, mean reward: 0.852 [0.500, 1.000], mean action: 3.655 [0.000, 6.000], mean observation: 165.016 [0.000, 255.000], loss: 0.381314, mean_absolute_error: 29.236226, mean_q: 34.238627, mean_eps: 0.292040
#  787334/1000000: episode: 3307, duration: 20.477s, episode steps: 476, steps per second: 23, episode reward: 374.000, mean reward: 0.786 [0.100, 1.000], mean action: 3.616 [0.000, 6.000], mean observation: 166.717 [0.000, 255.000], loss: 0.430485, mean_absolute_error: 29.712253, mean_q: 34.799836, mean_eps: 0.291614
#  787808/1000000: episode: 3308, duration: 20.545s, episode steps: 474, steps per second: 23, episode reward: 425.500, mean reward: 0.898 [0.500, 1.000], mean action: 3.620 [0.000, 6.000], mean observation: 164.893 [0.000, 255.000], loss: 0.415952, mean_absolute_error: 29.435584, mean_q: 34.468473, mean_eps: 0.291187
#  788278/1000000: episode: 3309, duration: 20.480s, episode steps: 470, steps per second: 23, episode reward: 397.500, mean reward: 0.846 [0.500, 1.000], mean action: 3.726 [0.000, 6.000], mean observation: 165.385 [0.000, 255.000], loss: 0.396191, mean_absolute_error: 29.117860, mean_q: 34.117490, mean_eps: 0.290762
#  788756/1000000: episode: 3310, duration: 20.555s, episode steps: 478, steps per second: 23, episode reward: 409.500, mean reward: 0.857 [0.500, 1.000], mean action: 3.672 [0.000, 6.000], mean observation: 165.641 [0.000, 255.000], loss: 0.378959, mean_absolute_error: 29.389511, mean_q: 34.394671, mean_eps: 0.290336
#  789231/1000000: episode: 3311, duration: 20.509s, episode steps: 475, steps per second: 23, episode reward: 395.000, mean reward: 0.832 [0.500, 1.000], mean action: 3.575 [0.000, 6.000], mean observation: 164.930 [0.000, 255.000], loss: 0.399793, mean_absolute_error: 29.258021, mean_q: 34.261508, mean_eps: 0.289907
#  789558/1000000: episode: 3312, duration: 12.765s, episode steps: 327, steps per second: 26, episode reward: 240.400, mean reward: 0.735 [-1.000, 1.000], mean action: 3.532 [0.000, 6.000], mean observation: 173.272 [0.000, 255.000], loss: 0.402459, mean_absolute_error: 29.006454, mean_q: 33.986949, mean_eps: 0.289545
#  790027/1000000: episode: 3313, duration: 20.436s, episode steps: 469, steps per second: 23, episode reward: 352.500, mean reward: 0.752 [0.500, 1.000], mean action: 3.531 [0.000, 6.000], mean observation: 165.715 [0.000, 255.000], loss: 0.394160, mean_absolute_error: 29.439405, mean_q: 34.474918, mean_eps: 0.289187
#  790438/1000000: episode: 3314, duration: 16.857s, episode steps: 411, steps per second: 24, episode reward: 342.600, mean reward: 0.834 [-1.000, 1.000], mean action: 3.623 [0.000, 6.000], mean observation: 172.813 [0.000, 255.000], loss: 0.392646, mean_absolute_error: 29.619400, mean_q: 34.669005, mean_eps: 0.288791
#  790839/1000000: episode: 3315, duration: 16.596s, episode steps: 401, steps per second: 24, episode reward: 291.100, mean reward: 0.726 [-1.000, 1.000], mean action: 3.661 [0.000, 6.000], mean observation: 173.168 [0.000, 255.000], loss: 0.414510, mean_absolute_error: 29.486685, mean_q: 34.552754, mean_eps: 0.288426
#  791318/1000000: episode: 3316, duration: 20.547s, episode steps: 479, steps per second: 23, episode reward: 437.000, mean reward: 0.912 [0.500, 1.000], mean action: 3.562 [0.000, 6.000], mean observation: 165.752 [0.000, 255.000], loss: 0.443561, mean_absolute_error: 30.103886, mean_q: 35.289380, mean_eps: 0.288030
#  791790/1000000: episode: 3317, duration: 20.484s, episode steps: 472, steps per second: 23, episode reward: 406.500, mean reward: 0.861 [0.500, 1.000], mean action: 3.441 [0.000, 6.000], mean observation: 165.714 [0.000, 255.000], loss: 0.373558, mean_absolute_error: 29.899232, mean_q: 35.017374, mean_eps: 0.287601
#  792254/1000000: episode: 3318, duration: 20.463s, episode steps: 464, steps per second: 23, episode reward: 415.000, mean reward: 0.894 [0.500, 1.000], mean action: 3.403 [0.000, 6.000], mean observation: 165.520 [0.000, 255.000], loss: 0.399880, mean_absolute_error: 29.649220, mean_q: 34.721098, mean_eps: 0.287180
#  792711/1000000: episode: 3319, duration: 20.562s, episode steps: 457, steps per second: 22, episode reward: 408.000, mean reward: 0.893 [0.500, 1.000], mean action: 3.567 [0.000, 6.000], mean observation: 165.401 [0.000, 255.000], loss: 0.409804, mean_absolute_error: 29.709831, mean_q: 34.819092, mean_eps: 0.286766
#  793180/1000000: episode: 3320, duration: 20.493s, episode steps: 469, steps per second: 23, episode reward: 416.500, mean reward: 0.888 [0.500, 1.000], mean action: 3.505 [0.000, 6.000], mean observation: 166.160 [0.000, 255.000], loss: 0.419313, mean_absolute_error: 29.759804, mean_q: 34.838804, mean_eps: 0.286350
#  793642/1000000: episode: 3321, duration: 20.672s, episode steps: 462, steps per second: 22, episode reward: 351.500, mean reward: 0.761 [0.500, 1.000], mean action: 3.545 [0.000, 6.000], mean observation: 165.609 [0.000, 255.000], loss: 0.386991, mean_absolute_error: 29.850045, mean_q: 34.920625, mean_eps: 0.285931
#  794080/1000000: episode: 3322, duration: 20.672s, episode steps: 438, steps per second: 21, episode reward: 353.000, mean reward: 0.806 [0.500, 1.000], mean action: 3.553 [0.000, 6.000], mean observation: 165.881 [0.000, 255.000], loss: 0.394740, mean_absolute_error: 29.485479, mean_q: 34.518048, mean_eps: 0.285526
#  794513/1000000: episode: 3323, duration: 20.620s, episode steps: 433, steps per second: 21, episode reward: 368.000, mean reward: 0.850 [0.500, 1.000], mean action: 3.651 [0.000, 6.000], mean observation: 165.646 [0.000, 255.000], loss: 0.403510, mean_absolute_error: 29.810306, mean_q: 34.904514, mean_eps: 0.285134
#  794950/1000000: episode: 3324, duration: 20.496s, episode steps: 437, steps per second: 21, episode reward: 381.000, mean reward: 0.872 [0.500, 1.000], mean action: 3.602 [0.000, 6.000], mean observation: 165.503 [0.000, 255.000], loss: 0.376469, mean_absolute_error: 30.249894, mean_q: 35.424258, mean_eps: 0.284741
#  795410/1000000: episode: 3325, duration: 20.485s, episode steps: 460, steps per second: 22, episode reward: 411.500, mean reward: 0.895 [0.500, 1.000], mean action: 3.496 [0.000, 6.000], mean observation: 165.783 [0.000, 255.000], loss: 0.386301, mean_absolute_error: 29.671060, mean_q: 34.746065, mean_eps: 0.284338
#  795884/1000000: episode: 3326, duration: 20.553s, episode steps: 474, steps per second: 23, episode reward: 406.500, mean reward: 0.858 [0.500, 1.000], mean action: 3.578 [0.000, 6.000], mean observation: 165.650 [0.000, 255.000], loss: 0.409394, mean_absolute_error: 29.973214, mean_q: 35.096424, mean_eps: 0.283919
#  796348/1000000: episode: 3327, duration: 20.613s, episode steps: 464, steps per second: 23, episode reward: 375.000, mean reward: 0.808 [0.100, 1.000], mean action: 3.716 [0.000, 6.000], mean observation: 166.016 [0.000, 255.000], loss: 0.415144, mean_absolute_error: 29.614524, mean_q: 34.672003, mean_eps: 0.283497
#  796815/1000000: episode: 3328, duration: 20.556s, episode steps: 467, steps per second: 23, episode reward: 348.700, mean reward: 0.747 [0.100, 1.000], mean action: 3.745 [0.000, 6.000], mean observation: 166.622 [0.000, 255.000], loss: 0.405579, mean_absolute_error: 29.836246, mean_q: 34.935383, mean_eps: 0.283078
#  797283/1000000: episode: 3329, duration: 20.454s, episode steps: 468, steps per second: 23, episode reward: 406.500, mean reward: 0.869 [0.500, 1.000], mean action: 3.585 [0.000, 6.000], mean observation: 165.717 [0.000, 255.000], loss: 0.390122, mean_absolute_error: 29.788564, mean_q: 34.910996, mean_eps: 0.282657
#  797688/1000000: episode: 3330, duration: 17.101s, episode steps: 405, steps per second: 24, episode reward: 352.900, mean reward: 0.871 [-1.000, 1.000], mean action: 3.615 [0.000, 6.000], mean observation: 172.560 [0.000, 255.000], loss: 0.414947, mean_absolute_error: 29.377226, mean_q: 34.392695, mean_eps: 0.282264
#  798155/1000000: episode: 3331, duration: 20.526s, episode steps: 467, steps per second: 23, episode reward: 361.000, mean reward: 0.773 [0.500, 1.000], mean action: 3.520 [0.000, 6.000], mean observation: 166.043 [0.000, 255.000], loss: 0.393233, mean_absolute_error: 29.520485, mean_q: 34.561830, mean_eps: 0.281872
#  798629/1000000: episode: 3332, duration: 20.624s, episode steps: 474, steps per second: 23, episode reward: 356.200, mean reward: 0.751 [0.100, 1.000], mean action: 3.515 [0.000, 6.000], mean observation: 165.793 [0.000, 255.000], loss: 0.407436, mean_absolute_error: 29.424447, mean_q: 34.437662, mean_eps: 0.281447
#  799104/1000000: episode: 3333, duration: 20.688s, episode steps: 475, steps per second: 23, episode reward: 379.000, mean reward: 0.798 [0.500, 1.000], mean action: 3.619 [0.000, 6.000], mean observation: 165.130 [0.000, 255.000], loss: 0.396518, mean_absolute_error: 30.187497, mean_q: 35.332087, mean_eps: 0.281021
#  799580/1000000: episode: 3334, duration: 20.648s, episode steps: 476, steps per second: 23, episode reward: 386.500, mean reward: 0.812 [0.500, 1.000], mean action: 3.609 [0.000, 6.000], mean observation: 166.080 [0.000, 255.000], loss: 0.419090, mean_absolute_error: 30.044213, mean_q: 35.160173, mean_eps: 0.280594
#  799988/1000000: episode: 3335, duration: 20.593s, episode steps: 408, steps per second: 20, episode reward: 349.000, mean reward: 0.855 [0.500, 1.000], mean action: 3.576 [0.000, 6.000], mean observation: 165.158 [0.000, 255.000], loss: 0.400759, mean_absolute_error: 29.807174, mean_q: 34.895389, mean_eps: 0.280196
#  800424/1000000: episode: 3336, duration: 20.517s, episode steps: 436, steps per second: 21, episode reward: 389.000, mean reward: 0.892 [0.500, 1.000], mean action: 3.631 [0.000, 6.000], mean observation: 167.642 [0.000, 255.000], loss: 0.413475, mean_absolute_error: 29.874866, mean_q: 34.992935, mean_eps: 0.279816
#  800872/1000000: episode: 3337, duration: 20.510s, episode steps: 448, steps per second: 22, episode reward: 384.500, mean reward: 0.858 [0.500, 1.000], mean action: 3.560 [0.000, 6.000], mean observation: 165.603 [0.000, 255.000], loss: 0.417680, mean_absolute_error: 29.782850, mean_q: 34.882658, mean_eps: 0.279419
# done, took 48613.192 seconds

# %% [markdown]
# ### continue training

# %%
# def build_callbacks_cont(env_name):
#     checkpoint_weights_filename = join(log_dir, 'dqn_' + env_name + '_weights_500000_add_{step}.h5f')
#     log_filename = join(log_dir,'dqn_{}_log.json'.format(env_name))
#     callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=25000)]
#     callbacks += [FileLogger(log_filename, interval=100)]
#     return callbacks

# callbacks_cont = build_callbacks_cont('AirSimCarRL')

# dqn = DQNAgent(model=model, nb_actions=num_actions, policy=policy, memory=memory,
#                processor=processor, nb_steps_warmup=50000, gamma=.99, target_model_update=10000,
#                train_interval=4, delta_clip=1.)
# dqn.compile(Adam(lr=.0001), metrics=['mae'])

# weights_filename = join(log_dir,'dqn_{}_weights_{}.h5f'.format('AirSimCarRL', 500000))
# dqn.load_weights(weights_filename)

# dqn.fit(env, nb_steps=2000000,
#         visualize=False,
#         verbose=2,
#         callbacks=callbacks_cont)

# %% [markdown]
# ### testing

# %%
# log_dir = 'logs'
# if not exists(log_dir):
#     os.makedirs(log_dir)
    
# weights_filename = join(log_dir,'dqn_{}_weights_{}.h5f'.format('AirSimCarRL', 1000000))
# dqn.load_weights(weights_filename)
# dqn.test(env, nb_episodes=10, visualize=True)
